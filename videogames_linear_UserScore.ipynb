# %% [markdown]
# <a href="https://colab.research.google.com/github/johanv26/Analitica/blob/main/videogames_linear_UserScore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Games

# %%
#descargar datos video_games
# !pip install wget
import wget
import pandas as pd
import numpy as np
#datos video juelgos-2016
#csv file id#
FILE_ID='1kMvhv1VpUpGmyyDZneZ7DaIpXZx9826Z'
url='https://drive.google.com/uc?export=download&id='+FILE_ID
#datos Colombia
import os.path as path
csv_file='Video_Games_Sales_as_at_22_Dec_2016.csv'
if not path.exists(csv_file):
  wget.download(url,csv_file)

gamesdf = pd.read_csv(csv_file)
gamesdf.head(20)
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.6/dist-packages (3.2)
#                                             Name  ... Rating
# 0                                     Wii Sports  ...      E
# 1                              Super Mario Bros.  ...    NaN
# 2                                 Mario Kart Wii  ...      E
# 3                              Wii Sports Resort  ...      E
# 4                       Pokemon Red/Pokemon Blue  ...    NaN
# 5                                         Tetris  ...    NaN
# 6                          New Super Mario Bros.  ...      E
# 7                                       Wii Play  ...      E
# 8                      New Super Mario Bros. Wii  ...      E
# 9                                      Duck Hunt  ...    NaN
# 10                                    Nintendogs  ...    NaN
# 11                                 Mario Kart DS  ...      E
# 12                   Pokemon Gold/Pokemon Silver  ...    NaN
# 13                                       Wii Fit  ...      E
# 14                            Kinect Adventures!  ...      E
# 15                                  Wii Fit Plus  ...      E
# 16                            Grand Theft Auto V  ...      M
# 17                 Grand Theft Auto: San Andreas  ...      M
# 18                             Super Mario World  ...    NaN
# 19  Brain Age: Train Your Brain in Minutes a Day  ...      E
#
# [20 rows x 16 columns]

# %%
gamesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
def userscore_fix(gamesdf):
  Xi=gamesdf
  frec_val=gamesdf['User_Score'].value_counts()
  mean=np.mean(frec_val.index[1:].astype('float64')) 
  Xi['User_Score'].replace(regex=["tbd"], value=mean,inplace=True)      
  Xi['User_Score'] = Xi['User_Score'].astype('float64');
  return gamesdf

# %%
gamesdf=userscore_fix(gamesdf)

# %%
gamesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %%
gamesdf['User_Score'].value_counts()
# Out:
# 4.989474    2425
# 7.800000     324
# 8.000000     290
# 8.200000     282
# 8.300000     254
#             ...
# 0.900000       2
# 2.300000       2
# 1.000000       2
# 9.700000       1
# 0.000000       1
# Name: User_Score, Length: 96, dtype: int64

# %%
#Paso 2: Particion entrenamiento y validacion
#Tamanio Xtrain 70%. Tamanio Xtest=30%
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
df_train, df_test =train_test_split(gamesdf,test_size=0.3)
col_sal= 'User_Score'
ytrain=df_train[col_sal]
ytest=df_test[col_sal]
df_train.drop(columns=col_sal,inplace=True)
df_test.drop(columns=col_sal,inplace=True)
ytrain
# Out:
# 12890    4.989474
# 7335          NaN
# 1626          NaN
# 10924    4.989474
# 369      7.500000
#            ...
# 1757     8.200000
# 14801    3.500000
# 14853    4.989474
# 12844         NaN
# 2039     8.200000
# Name: User_Score, Length: 11703, dtype: float64

# %%
#Completao de datos por moda de la salida Global sales
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
ytrain=imputer.fit_transform(pd.DataFrame(ytrain))
ytrain=ytrain.reshape(-1)

ytest=imputer.transform(pd.DataFrame(ytest))
ytest=ytest.reshape(-1)

print(ytrain.shape,ytest.shape)
# Out:
# (11703,) (5016,)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.hist(ytrain,bins=100)
plt.show()

#diagrama de caja

#caja->
plt.boxplot(ytrain)
plt.show()

# %%
print('Numero de valores nulos por columnas : \n')
for column in gamesdf:
  print(column,' ',gamesdf[column].isnull().sum())
# Out:
# Numero de valores nulos por columnas :
#
# Name   2
# Platform   0
# Year_of_Release   269
# Genre   2
# Publisher   54
# NA_Sales   0
# EU_Sales   0
# JP_Sales   0
# Other_Sales   0
# Global_Sales   0
# Critic_Score   8582
# Critic_Count   8582
# User_Score   6704
# User_Count   9129
# Developer   6623
# Rating   6769

# %%
#definir columnas 
col_scores = ['User_Score','Critic_Score','Critic_Count','User_Count']
# Strange values tbd

cat = ['Name','Platform','Genre','Publisher','Developer','Rating']
items = [] 
for i in cat:
    items += [list(gamesdf[i].value_counts().index)]
cat_names = dict(zip(cat, items))

# %%
gamesdf['Platform'].value_counts().index
# Out:
# Index(['PS2', 'DS', 'PS3', 'Wii', 'X360', 'PSP', 'PS', 'PC', 'XB', 'GBA', 'GC',
#        '3DS', 'PSV', 'PS4', 'N64', 'XOne', 'SNES', 'SAT', 'WiiU', '2600', 'GB',
#        'NES', 'DC', 'GEN', 'NG', 'SCD', 'WS', '3DO', 'TG16', 'PCFX', 'GG'],
#       dtype='object')

# %%
gamesdf[cat[1]].value_counts()
# Out:
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %%
frec_val=[]
for column in gamesdf:
  frec_val.append(gamesdf[column].value_counts())
print(frec_val[-2
          ])
# Out:
# Ubisoft                            204
# EA Sports                          172
# EA Canada                          167
# Konami                             162
# Capcom                             139
#                                   ...
# SpiderMonk                           1
# SuperBot Entertainment               1
# Treyarch, Infinity Ward              1
# Battlefront.com, 1C, 1C Company      1
# Master Creating                      1
# Name: Developer, Length: 1696, dtype: int64

# %%
#%% dummy transformer
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
class dummy_games(BaseEstimator,TransformerMixin):
    #inicializacion de clase y varaibles
    def __init__(self,col_scores, cat_usr):#constructor clase
        
        self.col_stats = col_scores#lista atributos tipo score
        self.cat_usr = cat_usr #lista de atributos categoricos

    def fit(self,X, *_):
        Xi = X.copy() #copiar dataset para no reemplazar original
        self.imputer_num = SimpleImputer(strategy="most_frequent")#crear imputador tipo modo
        self.a = Xi.columns[np.sum(Xi.isna())> 0] #encontrar columnas con datos faltantes
        #print(a)
        self.imputer_num.fit(Xi[self.a])# ajustar imputador
        
        Xi[self.a] = self.imputer_num.transform(Xi[self.a]) #evaluar  sobre datos imputador
        
        #codificar
        #only User_Score is cnahge the tbd most frequetn for mean.

        

        
        
        
        cat = []#codificar variables categoricas con ordinal encoder
        for i in self.cat_usr.keys():
            cat = cat + [[*self.cat_usr.get(i)]]
        self.col_cat_usr = OrdinalEncoder(categories=cat)
        Xi[[*self.cat_usr.keys()]] =self.col_cat_usr.fit_transform(Xi[[*self.cat_usr.keys()]])
        

        
        return self    

    def transform(self, X, *_):
        Xi = X.copy()
        Xi[self.a] = self.imputer_num.transform(Xi[self.a])

              
      #Funcion para userscore ya implemetnada
          
        Xi[[*self.cat_usr.keys()]] =self.col_cat_usr.transform(Xi[[*self.cat_usr.keys()]])
        
        #Fase de transformacion
        #
        
        return Xi
    
    def fit_transform(self,X,*_):
        self.fit(X)
        return self.transform(X)
#%%

# %% [markdown]
# Fit fill the empty values with most frequently and cofigre the calss.Transform hange the values with function to full float df.
#
# so in fit you manage the calss with the info of the datafram in transform, you use to return a dataframe with the values changed after the process step in making the class with the form using fit.

# %% [markdown]
# In rating developres is nan that mean no public developers, that can mean a data no se can use it.
#
# User score has the onlye change from the mean value becasuse tbd ts like a anan and is the mode solo we canhge it to mean.

# %%
dummy=dummy_games(col_scores=col_scores,cat_usr=cat_names)
dftrain_pre=dummy.fit_transform(df_train)
dftrain_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11703 entries, 12890 to 2039
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             11703 non-null  float64
#  1   Platform         11703 non-null  float64
#  2   Year_of_Release  11703 non-null  float64
#  3   Genre            11703 non-null  float64
#  4   Publisher        11703 non-null  float64
#  5   NA_Sales         11703 non-null  float64
#  6   EU_Sales         11703 non-null  float64
#  7   JP_Sales         11703 non-null  float64
#  8   Other_Sales      11703 non-null  float64
#  9   Global_Sales     11703 non-null  float64
#  10  Critic_Score     11703 non-null  float64
#  11  Critic_Count     11703 non-null  float64
#  12  User_Count       11703 non-null  float64
#  13  Developer        11703 non-null  float64
#  14  Rating           11703 non-null  float64
# dtypes: float64(15)
# memory usage: 1.4 MB

# %%
dftrain_pre #Falta modofical el valor para no repetir por el mas repetido
# Out:
#           Name  Platform  Year_of_Release  ...  User_Count  Developer  Rating
# 12890   1911.0       1.0           2006.0  ...         5.0      427.0     0.0
# 7335    9305.0       2.0           2010.0  ...         5.0        0.0     0.0
# 1626    1507.0       6.0           1998.0  ...         5.0        0.0     0.0
# 10924   2659.0       0.0           2009.0  ...         5.0      136.0     0.0
# 369       37.0       4.0           2010.0  ...       155.0        1.0     0.0
# ...        ...       ...              ...  ...         ...        ...     ...
# 1757   10560.0       1.0           2007.0  ...        66.0       66.0     0.0
# 14801   2022.0       2.0           2014.0  ...         4.0      299.0     0.0
# 14853    551.0       2.0           2016.0  ...         5.0      550.0     0.0
# 12844   7436.0      11.0           2011.0  ...         5.0        0.0     0.0
# 2039    6093.0       1.0           2012.0  ...        89.0       46.0     0.0
#
# [11703 rows x 15 columns]

# %%
dftrain_pre['Developer'].value_counts()
# Out:
# 0.0       4762
# 1.0        132
# 2.0        124
# 3.0        117
# 4.0         99
#           ...
# 988.0        1
# 1651.0       1
# 1578.0       1
# 652.0        1
# 1370.0       1
# Name: Developer, Length: 1470, dtype: int64

# %%
corr_matrix=dftrain_pre.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col0,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col1,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col2,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row3_col3,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col4,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row5_col5,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row6_col6,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row7_col7,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row8_col8,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row9_col9,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row10_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row11_col11,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row12_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row13_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col1{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col2,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row9_col4{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col3,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row5_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row8_col14,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col12{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col4,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col11{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col5,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col3{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col6,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col9{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col7,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row12_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col8,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col14,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col2,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col1,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col3,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col5,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col7,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col6,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col9,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col11,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row10_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row11_col4,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row13_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col9,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row3_col8,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row5_col4{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col1,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col5{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col11,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col5,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col8{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row0_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col3{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col0{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col3{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col4,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row10_col0,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row11_col7,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row12_col7{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col5,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col9,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row5_col0,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row6_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row12_col0{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col6,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row11_col0,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row13_col6{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col7{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col8{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col13{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col11{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col7,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row8_col0,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row9_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row12_col4,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col10{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col13{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row1_col14,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row3_col2,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row3_col14,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row4_col14{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col4,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row3_col6{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col6{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col8,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row5_col2,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row8_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row13_col1,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row13_col12,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row14_col9{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col13,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row5_col1,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row6_col14,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row9_col1,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row10_col7{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row2_col14,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row11_col10,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row12_col6,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row13_col14{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row3_col0,#T_c7fd5018_121e_11eb_a08c_0242ac1c0002row11_col5{
#             back

# %%
import seaborn as sns
sns.heatmap(corr_matrix,xticklabels=corr_matrix.columns.values,yticklabels=corr_matrix.columns.values)
plt.tight_layout()
#plt.savefig('results/corr_matrix.pdf', format='pdf', dpi=300)
plt.show()

# %%
print(f'la longitud de la salida ventas globales separados es entrenamiento={len(ytrain)} y test={len(ytest)}')
# Out:
# la longitud de la salida ventas globales separados es entrenamiento=11703 y test=5016

# %%
dftrain_pre2 = dftrain_pre.copy()
dftrain_pre2['Salida'] = ytrain
corr_matrix = abs(dftrain_pre2.corr())
corr_matrix['Salida'].sort_values(ascending=False)
# Out:
# Salida             1.000000
# Critic_Count       0.575486
# Critic_Score       0.361242
# Rating             0.346732
# Developer          0.168717
# User_Count         0.167898
# Other_Sales        0.154736
# EU_Sales           0.147563
# Global_Sales       0.144941
# NA_Sales           0.138387
# Name               0.137603
# Publisher          0.118888
# Platform           0.086351
# Year_of_Release    0.045160
# Genre              0.024472
# JP_Sales           0.009035
# Name: Salida, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(dftrain_pre2['Salida'],ytrain)#Cormporbar q salida si fue reemplazo por ytrain
plt.figure('1')
plt.scatter(dftrain_pre['Other_Sales'],ytrain)

# %%
ytrain.shape
# Out:
# (11703,)

# %%
col_scores
cat_names
# Out:
# {'Developer': ['Ubisoft',
#   'EA Sports',
#   'EA Canada',
#   'Konami',
#   'Capcom',
#   'EA Tiburon',
#   'Electronic Arts',
#   'Ubisoft Montreal',
#   'Visual Concepts',
#   'Omega Force',
#   "Traveller's Tales",
#   'Vicarious Visions',
#   'Activision',
#   'TT Games',
#   'Nintendo',
#   'THQ',
#   'Namco',
#   'Codemasters',
#   'Artificial Mind and Movement',
#   'Midway',
#   "Yuke's",
#   'Harmonix Music Systems',
#   'High Voltage Software',
#   'Maxis',
#   'Square Enix',
#   'Eurocom Entertainment Software',
#   'Arc System Works',
#   'FUN Labs',
#   'Neversoft Entertainment',
#   'Treyarch',
#   'From Software',
#   'TOSE',
#   'WayForward',
#   'Sonic Team',
#   'Sega',
#   'Griptonite Games',
#   'Rebellion',
#   'Radical Entertainment',
#   'Blitz Games',
#   'Milestone S.r.l',
#   'Rainbow Studios',
#   'Climax Group',
#   'Krome Studios',
#   'Exient Entertainment',
#   'Acclaim',
#   'Gearbox Software',
#   'Koei',
#   'SCEA San Diego Studios',
#   'KCET',
#   'Point of View',
#   'Toys for Bob',
#   'Digital Eclipse',
#   'Avalanche Software',
#   'Torus Games',
#   'Black Lantern Studios',
#   'BioWare',
#   'Terminal Reality',
#   'Amaze Entertainment',
#   '505 Games',
#   'EA Bright Light',
#   'Heavy Iron Studios',
#   'EA Games',
#   'SNK Playmore',
#   'Bandai Namco Games',
#   'Ubisoft Shanghai',
#   'Taito Corporation',
#   'Dimps Corporation',
#   'PopCap',
#   'Eutechnyx',
#   '989 Sports',
#   'Crystal Dynamics',
#   'Team 17',
#   'Criterion Games',
#   'EA DICE',
#   'Crave',
#   'Kush Games',
#   'Virtuos',
#   'SCEE London Studio',
#   'HB Studios Multimedia',
#   'Magic Pockets',
#   'Backbone Entertainment',
#   'Creative Assembly',
#   'Now Production',
#   'Beenox',
#   'CyberConnect2',
#   'LucasArts',
#   'Natsume',
#   'Double Helix Games',
#   'Nippon Ichi Software',
#   'EA Redwood Shores',
#   'Volition Inc.',
#   'Pandemic Studios',
#   'PlatinumGames',
#   'Blizzard Entertainment',
#   'Ubisoft Montpellier',
#   'Rockstar San Diego',
#   'Techland',
#   'Neko Entertainment',
#   'Sumo Digital',
#   'Altron',
#   'Tecmo',
#   'Io Interactive',
#   'Zoo Games',
#   'n-Space',
#   'Intelligent Systems',
#   'Argonaut Games',
#   'Destineer',
#   'Ubisoft Paris',
#   'Atlus',
#   'Mass Media',
#   'City Interactive',
#   'Namco Bandai Games',
#   'Vicious Cycle',
#   'Blue Castle Games',
#   'Ubisoft Quebec',
#   'Team Ninja',
#   'Black Box',
#   'Papaya Studios',
#   'Infinity Ward',
#   '2K Sports',
#   'Pipeworks Software, Inc.',
#   'Spike',
#   'Firebrand Games',
#   '3DO',
#   'Edge of Reality',
#   'SCE Japan Studio',
#   'SCEA',
#   'Level 5',
#   'Monkey Bar Games',
#   'TT Fusion',
#   'Gust',
#   'EA LA',
#   'Rare Ltd.',
#   'Page 44 Studios',
#   'Behaviour Interactive',
#   'Asobo Studio',
#   'Take-Two Interactive',
#   'Obsidian Entertainment',
#   'Raven Software',
#   'Hudson',
#   'SquareSoft',
#   'Hudson Soft',
#   '7 Studios',
#   'Zoe Mode',
#   'Z-Axis, Ltd.',
#   'Kojima Productions',
#   'Data Design Interactive',
#   'BudCat',
#   'Paradigm Entertainment',
#   'Neverland',
#   'Visceral Games',
#   'Game Arts',
#   'Kuju Entertainment',
#   'Tantalus Interactive',
#   'Blue Tongue Entertainment',
#   'Telltale Games',
#   '49Games',
#   'High Moon Studios',
#   'Rockstar North',
#   'Relic',
#   'Visual Impact',
#   'Grasshopper Manufacture',
#   'Digital Illusions',
#   'Farsight Studios',
#   'Sports Interactive',
#   'Ludia Inc.',
#   'Racjin',
#   'Next Level Games',
#   'Bandai',
#   'The Sims Studio',
#   'Valve Software',
#   'Firaxis Games',
#   'HAL Labs',
#   'Cavia Inc.',
#   'Dreamcatcher',
#   'Acquire',
#   'UFO Interactive',
#   'Warthog',
#   'Microsoft Game Studios',
#   'Full Fat',
#   'Sand Grain Studios',
#   'Creat Studios',
#   'Sting',
#   'DC Studios',
#   'Stormfront Studios',
#   'KCEJ',
#   'Genki',
#   'Haemimont',
#   '1st Playable Productions',
#   'Epic Games',
#   'Konami Computer Entertainment Hawaii',
#   'Atomic Planet Entertainment',
#   'Bugbear',
#   'Left Field Productions',
#   'Tri-Ace',
#   'Treasure',
#   'Free Radical Design',
#   'Crytek',
#   'EA Black Box',
#   'Powerhead Games',
#   'Bethesda Softworks',
#   'Gaijin Entertainment',
#   'Media Vision',
#   'Bizarre Creations',
#   'Rocksteady Studios',
#   'Pivotal Games',
#   'Starbreeze',
#   'Ubisoft Romania',
#   'Shaba Games',
#   'Inti Creates',
#   'Compile Heart',
#   'Sensory Sweep',
#   'Atlus Co.',
#   'Spark Unlimited',
#   'FreeStyleGames',
#   'Monolith Productions',
#   'Game Republic',
#   'Koei Tecmo Games',
#   "Shin'en",
#   'Insomniac Games',
#   'EA Montreal',
#   'Acclaim Studios Cheltenham',
#   'Webfoot Technologies',
#   'Frontier Developments',
#   'Engine Software',
#   'Monster Games Inc.',
#   'Tamsoft',
#   'Pyro Studios',
#   'Q Entertainment',
#   'Spike Chunsoft',
#   'Microids',
#   'Etranges Libellules',
#   'Helixe',
#   'Camelot Software Planning',
#   'Shiny Entertainment',
#   'Naughty Dog',
#   'Deep Silver',
#   'Core Design Ltd.',
#   '5TH Cell',
#   'Sidhe Interactive',
#   'MumboJumbo',
#   'Image Epoch, Imageepoch',
#   'Virtual Toys',
#   'Indies Zero',
#   'Digital Extremes',
#   'Coresoft',
#   'Secret Level',
#   'Matrix Software',
#   'Avalanche Studios',
#   'Piranha Bytes',
#   'Sanzaru Games',
#   'Collision Studios',
#   'Eden Studios',
#   'InXile Entertainment',
#   'Blitz Games Studios',
#   'Falcom',
#   'Atari',
#   'Disney Interactive Studios',
#   'Human Soft',
#   'Cyanide',
#   'Bethesda Game Studios',
#   'Art',
#   'Mistic Software',
#   'Sega AM2',
#   'Climax Group, Climax Studios',
#   'Opus',
#   'Day 1 Studios',
#   'Nixxes Software',
#   'Rockstar Leeds',
#   'Juice Games',
#   'Gameloft',
#   'Arika',
#   'SCEE',
#   'Robomodo',
#   'Monolith Soft',
#   'Snowblind Studios',
#   'Paradox Development',
#   'Airtight Games',
#   'Marvelous Inc.',
#   'Exakt',
#   'Big Ant Studios',
#   'MachineGames',
#   'Saffire',
#   'Red Storm Entertainment',
#   'Giants Software',
#   'Xpec',
#   'Alfa System',
#   'Luxoflux, Inc.',
#   'Razorworks Studios',
#   'Clover Studio',
#   'Black Ops Entertainment',
#   'Clap Hanz',
#   'Majesco Games, Majesco',
#   'Starfish',
#   'id Software',
#   'MTO',
#   'Zipper Interactive',
#   'Reflections Interactive',
#   'Oxygen Interactive',
#   'Nordic Games Publishing',
#   'CD Projekt Red Studio',
#   'Incinerator Games',
#   'Arkane Studios',
#   'Jack of All Games',
#   'Amusement Vision',
#   'Namco Bandai Games America, Namco Bandai Games',
#   'System 3',
#   'Frogwares',
#   'Sandlot',
#   'Aki Corp.',
#   'Wow Entertainment',
#   'Coyote Console',
#   'Revolution Software',
#   '5pb',
#   'Headstrong Games',
#   'Gas Powered Games',
#   'Jaleco Entertainment',
#   'Polyphony Digital',
#   'Cauldron Ltd.',
#   'Digital Kids',
#   'Full-Fat',
#   'Big Blue Bubble Inc.',
#   'Rockstar Toronto',
#   'KCEO',
#   'h.a.n.d. Inc.',
#   'Takara Tomy',
#   'Ganbarion',
#   'Gorilla Systems',
#   'Sony Bend',
#   'Cat Daddy Games',
#   'Irem',
#   'Blue Byte',
#   'Sucker Punch',
#   'ImaginEngine',
#   'Artoon',
#   'Legacy Interactive',
#   'Infinite Interactive',
#   'Bits Studios',
#   'Vanillaware',
#   'DTP Entertainment',
#   'Remedy Entertainment',
#   'Vigil Games',
#   'Hypnotix',
#   'Storm City Games',
#   'Bluepoint Games',
#   'Humongous Entertainment',
#   'Red Fly Studio',
#   'HotGen',
#   'Silicon Knights',
#   'K2 LLC',
#   'Bungie',
#   'Torus Games, Little Orbit',
#   'EA Chicago',
#   'Codemasters Birmingham',
#   'Marvelous Entertainment',
#   'Kalypso',
#   'Ensemble Studios',
#   'Koei, Omega Force',
#   'Bungie Software, Bungie',
#   'Retro Studios',
#   'Mercury Steam',
#   'Nex Entertainment',
#   'Kemco',
#   'Takara',
#   'Evolution Studios',
#   'NetherRealm Studios',
#   'Hydravision',
#   'Endemol',
#   'Rage Software',
#   'Atari, Atari SA',
#   'UBlart Montpellier',
#   'Propaganda Games',
#   'Skyworks Technologies',
#   'Pam Development',
#   'Rising Star Games',
#   'Lionhead Studios',
#   'DONTNOD Entertainment',
#   'Surreal Software',
#   'Destination Software',
#   'Handheld Games',
#   'Red Tribe',
#   'Titus Software',
#   'Pacific Coast Power & Light',
#   'Longtail Studios',
#   'Frame Studios Interactive',
#   'NanaOn-Sha',
#   'Artech Studios',
#   'Studio Liverpool',
#   'Attention To Detail',
#   'Little Orbit',
#   'Blue Fang Games',
#   'Success',
#   'EA Salt Lake',
#   'Eidos Interactive',
#   'Saber Interactive',
#   'Big Huge Games',
#   'Incognito Inc.',
#   'Eighting',
#   'UDS',
#   'Prope',
#   'Sony Online Entertainment',
#   'Slightly Mad Studios',
#   'Guerrilla',
#   '4J Studios',
#   'CokeM Interactive',
#   'Jupiter Corporation',
#   'EKO Software',
#   'Novarama',
#   'Blade Interactive',
#   '2K Marin',
#   'GRIN',
#   '2K Games',
#   'Project Aces',
#   'Wizarbox',
#   'ValuSoft',
#   'Tango Gameworks',
#   'Team Fusion',
#   'Midway Studios - Austin',
#   'Ready at Dawn',
#   'Artefacts Studio',
#   'Triumph Studios',
#   'Venom Games',
#   'Other Ocean Interactive',
#   'Ninja Theory',
#   'Starfish SD',
#   'SCE Santa Monica',
#   'ArtePiazza',
#   'Razorback Developments',
#   'Idea Factory',
#   'Keen Games',
#   'FrontLine Studios',
#   'Ignition Entertainment',
#   'Marvelous',
#   'FuRyu',
#   'Artdink',
#   'Avanquest Software',
#   'Kadokawa',
#   'Hudson Entertainment',
#   'Various',
#   'Bec',
#   'Crawfish Interactive',
#   'Supersonic Software',
#   '2K Czech',
#   'Aspyr',
#   'Cing',
#   'SimBin',
#   'Lexis Numerique, Virtual Toys',
#   'Ghost Games',
#   'Ubisoft Vancouver',
#   'Ryu ga Gotoku Studios',
#   'ArenaNet',
#   'Nd Cube',
#   'Magellan Interactive',
#   'Runecraft',
#   'High Impact Games',
#   'Nihilistic',
#   'Croteam',
#   'Gusto Games',
#   '4A Games',
#   'Raylight Studios',
#   'Paradox Development Studio',
#   'Bullfrog Productions',
#   'Slant Six',
#   'KCE Studios',
#   'ChunSoft',
#   'Larian Studios',
#   'Smart Bomb Interactive',
#   'Stainless Games',
#   'Respawn Entertainment',
#   'Mastiff',
#   'Massive Entertainment',
#   'Smilebit',
#   'Funcom',
#   'Black Rock Studio',
#   'Paon Corporation',
#   'Quantic Dream',
#   'Blue Shift',
#   'iNiS',
#   'Lightning Fish Games',
#   'Lucky Chicken',
#   'VIS Entertainment',
#   'EA Sports, EA Vancouver',
#   'Access Games',
#   'FireFly Studios',
#   'D3Publisher',
#   'Turn 10',
#   'Deibus Studios',
#   'DreamFactory',
#   'Light Weight',
#   'Bohemia Interactive',
#   'Tri-Crescendo',
#   'AI',
#   'Beyond Reality',
#   'Empire Interactive',
#   'Daedalic Entertainment',
#   'Mad Doc Software',
#   'Piranha Games',
#   'Eighting/Raizing',
#   'Kaos Studios',
#   'FeelPlus',
#   'Trion Worlds',
#   'Ratbag',
#   'IR Gurus',
#   'CAProduction',
#   'Jester Interactive',
#   'Hellbent Games',
#   'Black Isle Studios',
#   'Brash Entertainment',
#   'Ubisoft Milan',
#   'Teyon',
#   'RED Entertainment',
#   'Rovio Mobile, Rovio Entertainment',
#   'KCEA',
#   'Zombie Studios',
#   'Irrational Games',
#   '343 Industries',
#   'Acclaim Studios Austin',
#   'Yager',
#   'Ivory Tower',
#   'Ubisoft Toronto',
#   'Ubisoft Reflections',
#   'WXP',
#   'SuperVillain Studios',
#   'Genuine Games',
#   'Wideload Games Inc.',
#   'Renegade Kid',
#   'Super X Studios',
#   'Pseudo Interactive',
#   'Ubisoft Casablanca',
#   'Treyarch, Shaba Games',
#   'Shift',
#   'Psyonix',
#   'Eugen Systems',
#   'Conspiracy Entertainment',
#   'Panic Button',
#   'Ion Storm',
#   'Double Fine Productions',
#   'Razorworks',
#   'Indie Built',
#   'Hijinx Studios',
#   'Oddworld Inhabitants',
#   'Game Machine Studios',
#   'Magenta Software',
#   'Examu',
#   'Tantatus',
#   'KING Art',
#   'Million',
#   'O-Games',
#   'Mobius Entertainment',
#   '3d6 Games',
#   'Wicked Witch Software',
#   'Empire Oxford',
#   'Monumental Games',
#   'Iron Galaxy Studios',
#   'United Front Games',
#   'Totally Games',
#   'SCEI',
#   'Neverland, Idea Factory',
#   'Gaming Minds Studios',
#   'Cranky Pants Games',
#   'Adrenium',
#   'Nintendo, Nd Cube',
#   'Petroglyph',
#   'LucasArts, Krome Studios',
#   'High Voltage Software, Backbone Entertainment',
#   'Brain Toys',
#   'Idol Minds',
#   'Reality Pump',
#   'Genius Sonority Inc.',
#   'Kojima Productions, Moby Dick Studio',
#   'Planet Moon Studios',
#   'Cattle Call',
#   'Splash Damage',
#   'Cave',
#   'Smack Down Productions',
#   'Zoe Mode, HB Studios Multimedia',
#   'Hitmaker',
#   'Cooking Mama Limited',
#   'Eidos Montreal',
#   'GSC Game World',
#   'Namco Bandai Games America',
#   'Pipe Dream Interactive',
#   'Bigbig Studios',
#   'AWE Games',
#   'RedLynx',
#   'Disney Interactive',
#   'Spellbound',
#   'Polygon Magic',
#   'Bam Entertainment',
#   'SNK',
#   'Midway Studios - San Diego',
#   'Capcom Vancouver',
#   'Inti',
#   'Red Storm Entertainment, Ubisoft Montreal',
#   'Yacht Club Games',
#   'Climax Studios',
#   'NuFX',
#   'Lost Toys',
#   'M2',
#   'Gogii Games',
#   'Melbourne House',
#   'Land Ho!',
#   'Valuewave Co.,Ltd.',
#   'Colossal Order',
#   'Pocketeers',
#   'Spiders',
#   'K2',
#   'Graffiti Entertainment',
#   'MagicWand',
#   'Suzak',
#   'Ubisoft Bulgaria',
#   'SEGA Racing Studio',
#   'Flight-Plan',
#   'Vivendi Games',
#   'EA Sports Big',
#   'Eden',
#   'Vingt-et-un Systems',
#   'Creatures Inc.',
#   'Virtucraft',
#   'Kylotonn',
#   'Coyote Developments',
#   'Icon Games',
#   'Big Sky Software',
#   'Human Soft, Ivolgamus',
#   'Sledgehammer Games',
#   'City Interactive, Deck 13',
#   'Pronto Games',
#   'Overkill Software',
#   'Velez & Dubail',
#   'KnowWonder',
#   'Alpha Unit',
#   'Game Freak',
#   'Turtle Rock Studios',
#   '3G Studios',
#   'Inevitable Entertainment',
#   'Activision Value',
#   'Hit Maker',
#   'Bullets',
#   'Angel Studios',
#   'Nordcurrent',
#   'Jellyvision, Iron Galaxy Studios',
#   'Bungie Software',
#   'Trickstar Games',
#   'Backbone Vancouver',
#   'Brownie Brown',
#   'Deck 13',
#   'Sonic Powered',
#   'Zerodiv',
#   'Arcade Moon',
#   'Media Molecule',
#   'Monte Cristo Multimedia',
#   'LSP',
#   'Spicy Horse',
#   'Impulse Games',
#   'Nintendo, Nintendo Software Technology',
#   'Kouyousha',
#   'Her Interactive',
#   'WideScreen Games',
#   'EA Canada, Nihilistic',
#   'VU Games',
#   'WinkySoft',
#   'Illusion Softworks',
#   'Human Head Studios',
#   'Cyanide, Cyanide Studios',
#   'Jellyvision',
#   'Phoenix Games Studio',
#   'The Game Factory',
#   'Barnhouse Effect',
#   'Crystal Dynamics, Nixxes Software',
#   'Swordfish Studios',
#   'WorkJam',
#   'Gearbox Software, 3D Realms',
#   'Epicenter Studios',
#   'Kush Games, Visual Concepts',
#   'Freedom Factory Studios',
#   'Ubisoft, Sensory Sweep',
#   'DSI Games',
#   'Graphic State',
#   'RFX Interactive',
#   'Outrage Games',
#   'Two Tribes',
#   'Cosmigo',
#   'Cyberlore Studios',
#   'Microvision',
#   'Rockstar London',
#   'Overworks',
#   'AQ Interactive',
#   'Amuze',
#   'Experience Inc.',
#   'Tomy Corporation',
#   'Most Wanted Entertainment',
#   'Sega Studios San Francisco',
#   '2K Australia',
#   'Easy Interactive',
#   'Micro Cabin',
#   'Ascaron Entertainment GmbH, Ascaron Entertainment',
#   'SkyRiver Studios',
#   'Ubisoft Paris, Ubisoft Montpellier',
#   'Nadeo',
#   'Black Ship Games',
#   'Ascaron Entertainment GmbH',
#   'Playrix Entertainment',
#   'Rockstar Studios',
#   'Stormregion',
#   'Broadsword Interactive',
#   'SouthPeak Games',
#   'Deep Silver Dambuster Studios',
#   'iWin',
#   'Namco Bandai Games, Monkey Bar Games',
#   'Lexis Numerique',
#   'Isopod Labs',
#   'Ubisoft Reflections, Ivory Tower',
#   'Infinity Ward, Sledgehammer Games',
#   'Global A',
#   'Koolhaus Games',
#   'Danger Close',
#   'Marvelous AQL',
#   'Terminal Reality, 4mm Games',
#   'TimeGate Studios',
#   'TOYBOX',
#   'Zed Two Limited',
#   'Moss',
#   'Gorilla Games',
#   'Games Farm',
#   'Nitro Games',
#   'Santa Cruz Games',
#   'Hangar 13',
#   'Darkworks',
#   'Gratuitous Games',
#   'Loose Cannon Studios',
#   'SCE Studio Cambridge',
#   'T&E Soft',
#   'Climax Entertainment',
#   'Cerasus Media',
#   'Idea Factory, Compile Heart',
#   'Paradox Interactive',
#   'Mercury Steam, Alchemic Productions',
#   'Anchor',
#   'Nikitova Games',
#   'Dancing Dots',
#   'Deadline Games',
#   'Savage Entertainment',
#   'Psygnosis',
#   'Aspect',
#   'Coldwood Interactive',
#   'Pendulo Studios',
#   'Epic Games, People Can Fly',
#   'SCEJ',
#   'Ambrella',
#   'Taniko',
#   'GungHo',
#   'Ubisoft, Ubisoft Montreal',
#   'id Software, Raven Software',
#   '8ing/Raizing',
#   'Appaloosa Interactive',
#   'Digital Mayhem',
#   'Mistwalker, Artoon',
#   'GenePool',
#   'David A. Palmer Productions',
#   'N-Fusion Interactive Entertainment Corp.',
#   'Shift, Bandai Namco Games',
#   'Vicious Cycle, Little Orbit',
#   'Planet Interactive',
#   'Gunnar Games',
#   'Oberon Media',
#   'Iridon Interactive AB',
#   '1C, Ino-Co, 1C Company',
#   'Nautilus',
#   'THQ Australia',
#   'Q-Games',
#   '2K Play',
#   'Silicon Studio',
#   "Swingin' Ape",
#   'Wargaming.net',
#   'Vivarium',
#   'WBIE',
#   'Impressions Games',
#   'Clockwork Games',
#   'Buzz Monkey',
#   'Kuusou Kagaku',
#   'Andamiro U.S.A. Corp.',
#   'Acclaim Studios Manchester',
#   'Fluid Studios',
#   'Computer Artworks',
#   'Slam Games',
#   'SScholastic Media',
#   'Fall Line Studio',
#   'Best Way',
#   'Volatile Games',
#   'Activision, Behaviour Interactive',
#   'Vanpool',
#   'Global Star Software',
#   'Studio 33',
#   'Digital Fiction',
#   'Purple Hills',
#   '1C:Ino-Co',
#   'Mucky Foot Productions',
#   'Neon Studios, Kaiko',
#   'Game Life',
#   'Fuse Games Limited',
#   'EA Sports, EA Canada',
#   'S-Neo',
#   'Capcom, Pipeworks Software, Inc.',
#   'Seven45 Studios',
#   'DMA Design',
#   'Kando Games',
#   'Ironclad Games',
#   'Midway Studios - Los Angeles',
#   'Ready at Dawn, SCE Santa Monica',
#   '5000ft',
#   'Mac Play, MacPlay',
#   'Blue Omega',
#   'Akella',
#   'CyberConnect2, Racjin',
#   'PuzzleKings',
#   '1C, 1C Company',
#   'Backbone Emeryville',
#   'EA Vancouver',
#   'Warner Bros. Interactive Entertainment, NetherRealm Studios',
#   'Chris Sawyer',
#   'Kodiak Interactive',
#   'Big Fish Games',
#   'Starsphere Interactive',
#   'People Can Fly',
#   'Top Heavy Studios',
#   'BeeWorks',
#   'Kunos Simulazioni',
#   'Mad Doc Software, Rockstar Vancouver',
#   'Zen Studios',
#   'Guerilla Cambridge',
#   'War Drum Studios',
#   'Metro',
#   'Playlogic, The Game Factory',
#   'OneNine Studios',
#   'SunSoft',
#   'SCS Software',
#   'Noise Factory',
#   'Quicksilver Software',
#   'Targem Games, TopWare Interactive',
#   'Bandai Namco Games, Artdink',
#   'Omega Force, Koei Tecmo Games',
#   'CCP',
#   'Immersion Software & Graphics',
#   'Nobilis',
#   'Game Sauce',
#   'Farsight Studios, Crave',
#   '2XL Games',
#   'Deep Fried Entertainment',
#   'Whitebear',
#   'Foreign Media',
#   'Axis Entertainment',
#   'Hothouse Creations',
#   'Electronic Arts, Rebellion',
#   'Sennari Interactive',
#   'Scientifically Proven',
#   'Babylon Software',
#   'Metanet Software Inc., SilverBirch Studios',
#   'Team Ninja, Tecmo',
#   'Ritual Entertainment, Avalanche Software',
#   'Gravity-I',
#   'Spark Unlimited, comcept',
#   'Classic Media Distribution Limited',
#   'Big John Games',
#   'Ubisoft Nagoya',
#   'Digital Anvil',
#   'Pocket Studios',
#   'BottleRocket Entertainment',
#   'Studio Saizensen',
#   'Autumn Moon',
#   'Mistwalker',
#   'Naps Team',
#   'The Fun Pimps Entertainment LLC',
#   'Amanita Design',
#   'Irrational Games, 2K Marin',
#   'Firehazard Studio',
#   'GameMill Publishing, 1st Playable Productions',
#   'Cunning Developments',
#   'The Behemoth',
#   'Aqua Pacific, In2Games',
#   'Funatics Software, Funatics',
#   'Nintendo EAD Tokyo',
#   'Seta Corporation',
#   'ITL',
#   'Gameinvest',
#   'Asylum Entertainment',
#   'Guildford Studio',
#   'Epics',
#   'Direct Action Games',
#   'Dimps Corporation, Namco Bandai Games',
#   'Red Storm Entertainment, Ubisoft Paris',
#   'Frozenbyte, Inc.',
#   'MileStone Inc.',
#   'Software Creations',
#   'Mad Catz',
#   'Fox Interactive',
#   'Doki Denki',
#   'Stealth Studios',
#   '1C: Maddox Games',
#   'EA Canada, EA Vancouver',
#   'Blue Byte, Related Designs',
#   'Rocksteady Studios, Virtuos',
#   'Gaijin Games',
#   'Taito Corporation, 505 Games',
#   'Steel Monkeys',
#   'Telegames',
#   'PopTop Software',
#   'MicroProse, n-Space',
#   'Dreamworks Interactive',
#   'Griffin International',
#   'Trine Games',
#   'Westwood Studios',
#   'Fatshark AB',
#   'Noise Inc.',
#   'EM Studios',
#   'Project Soul',
#   'Sims',
#   'Team Bondi',
#   'Harmonix Music Systems, Demiurge Studios',
#   'Vanilla Ware',
#   'Prope, Kadokawa',
#   'Bongfish',
#   'B-Alive',
#   'Pitbull Syndicate',
#   'Presto Studios',
#   'Digital Embryo',
#   'Cinegroupe',
#   'Tecmo, Ntreev Soft',
#   'Tilted Mill',
#   'Phoenix Interactive Entertainment',
#   'EA Seattle',
#   'Interplay',
#   'CI Games',
#   'WB Games Montreal',
#   'Blast! Entertainment Ltd',
#   'Amble',
#   'THQ Digital Studio Phoenix',
#   'Koei/Inis',
#   'Arkedo Studio',
#   'Introversion, Double Eleven',
#   'Eutechnyx, Deep Silver',
#   'SuperMassive Games',
#   'SCi',
#   'Klein Computer Entertainment',
#   'Buena Vista Games',
#   'Otomate',
#   'Mix Max',
#   'Delphine Software International',
#   'The Code Monkeys',
#   'Evolution Games',
#   'Spike Chunsoft, Chime',
#   'Zig Zag',
#   'Lab Rats Games',
#   'Mitchell',
#   'Dice, Danger Close',
#   'UGA',
#   'Spike, Namco Bandai Games',
#   'Happy Happening',
#   'Machatin, Inc.',
#   'eGames',
#   'Blizzard North',
#   'Tetris Online, Inc',
#   'NaturalMotion',
#   'Majesco Games',
#   'Interchannel',
#   'BattleBorne',
#   'Mentor Interactive',
#   'Career Soft',
#   'KCEK',
#   'Tommo',
#   'ZootFly',
#   'Disney Interactive Studios, Land Ho!',
#   'King of the Jungle',
#   'Locomotive Games',
#   'Egosoft',
#   'Team 17, Two Tribes',
#   'Extra Mile Studios',
#   'Knowledge Adventure Inc.',
#   'Inland Productions',
#   'Milestone, Milestone S.r.l',
#   'Opera House',
#   'FASA Studio',
#   'Studio Gigante',
#   'Glyphic Entertainment',
#   'Blue Tongue',
#   'XS Games',
#   'Neopica',
#   'Activision, FreeStyleGames',
#   'Simon & Schuster',
#   'Jet Black Games',
#   'Twelve Games',
#   'CiRCLE',
#   'SCE/WWS, Media Molecule',
#   'Curious Pictures',
#   'Junction Point',
#   'Kung Fu Factory',
#   'Capcom, QLOC',
#   'Infogrames',
#   'Sanuk Games',
#   'Red Tribe, Brash Entertainment',
#   'Pyramid',
#   ...],
#  'Genre': ['Action',
#   'Sports',
#   'Misc',
#   'Role-Playing',
#   'Shooter',
#   'Adventure',
#   'Racing',
#   'Platform',
#   'Simulation',
#   'Fighting',
#   'Strategy',
#   'Puzzle'],
#  'Name': ['Need for Speed: Most Wanted',
#   'Madden NFL 07',
#   'Ratatouille',
#   'LEGO Marvel Super Heroes',
#   'FIFA 14',
#   'Terraria',
#   'LEGO Jurassic World',
#   'LEGO Star Wars II: The Original Trilogy',
#   'Lego Batman 3: Beyond Gotham',
#   'FIFA Soccer 13',
#   'Cars',
#   'The LEGO Movie Videogame',
#   'LEGO The Hobbit',
#   'FIFA 15',
#   'Madden NFL 08',
#   'Angry Birds Star Wars',
#   'Monopoly',
#   'LEGO Harry Potter: Years 5-7',
#   'Skylanders SWAP Force',
#   'LEGO Batman 2: DC Super Heroes',
#   'FIFA Soccer 08',
#   'The Sims 2',
#   'Madden NFL 06',
#   'LEGO The Lord of the Rings',
#   "LEGO Marvel's Avengers",
#   'Lego Star Wars: The Force Awakens',
#   'NBA Jam',
#   'Need for Speed: ProStreet',
#   'Spider-Man 3',
#   'Pro Evolution Soccer 2012',
#   'Skylanders: SuperChargers',
#   'Harry Potter and the Order of the Phoenix',
#   'Wall-E',
#   "Surf's Up",
#   'The Amazing Spider-Man 2 (2014)',
#   'Skylanders: Trap Team',
#   'LEGO Batman: The Videogame',
#   'FIFA Soccer 11',
#   'Major League Baseball 2K11',
#   'LEGO Star Wars III: The Clone Wars',
#   'LEGO Pirates of the Caribbean: The Video Game',
#   'Tomb Raider: Legend',
#   'FIFA 12',
#   'Need for Speed Carbon',
#   'LEGO Indiana Jones: The Original Adventures',
#   'Star Wars The Clone Wars: Republic Heroes',
#   'Harry Potter and the Half-Blood Prince',
#   'Need For Speed: Undercover',
#   'FIFA Soccer 10',
#   "Harry Potter and the Sorcerer's Stone",
#   'Warriors Orochi 3',
#   'DiRT 2',
#   'WWE SmackDown vs. Raw 2009',
#   'Up',
#   'Tiger Woods PGA Tour 08',
#   'pro evolution soccer 2011',
#   'Harry Potter and the Goblet of Fire',
#   'Pro Evolution Soccer 2010',
#   'Marvel: Ultimate Alliance 2',
#   'The Incredibles: Rise of the Underminer',
#   'Brunswick Pro Bowling',
#   'Major League Baseball 2K10',
#   'Iron Man',
#   'Monsters vs. Aliens',
#   'Ben 10 Ultimate Alien: Cosmic Destruction',
#   'Disney Infinity 2.0: Marvel Super Heroes',
#   'Avatar: The Game',
#   "Assassin's Creed IV: Black Flag",
#   'The Incredible Hulk',
#   'The Sims 3',
#   'Pro Evolution Soccer 2013',
#   'Adventure Time: Finn & Jake Investigations',
#   'Minecraft',
#   'NBA 2K11',
#   'Madden NFL 13',
#   'Ghostbusters: The Video Game',
#   'The Walking Dead: Season One',
#   'Michael Jackson: The Experience',
#   'Prince of Persia: The Forgotten Sands',
#   'FIFA Soccer 07',
#   'Madagascar: Escape 2 Africa',
#   'Transformers: Revenge of the Fallen (XBox 360, PS3, & PC Versions)',
#   'Rapala Pro Bass Fishing 2010',
#   'Cars: Race-O-Rama',
#   'The Sims 2: Pets',
#   'Spider-Man: Friend or Foe',
#   'Disney Infinity',
#   'The Golden Compass',
#   'Rayman Origins',
#   'Spider-Man: Web of Shadows',
#   "Peter Jackson's King Kong: The Official Game of the Movie",
#   'The Amazing Spider-Man (Console Version)',
#   'Rugby World Cup 2015',
#   'Just Dance 2014',
#   'LEGO Harry Potter: Years 1-4',
#   'X-Men: The Official Game',
#   'MX vs. ATV Untamed',
#   'Tiger Woods PGA Tour 07',
#   '007: Quantum of Solace',
#   'The BIGS 2',
#   'Just Dance 2016',
#   'Turbo: Super Stunt Squad',
#   'WWE All Stars',
#   'FIFA World Cup Germany 2006',
#   "You Don't Know Jack",
#   'Cars 2',
#   'Madden NFL 09',
#   'Open Season',
#   'G.I. Joe: The Rise of Cobra',
#   'Star Wars: The Force Unleashed',
#   'Harry Potter and the Chamber of Secrets',
#   'Ice Age 2: The Meltdown',
#   'FIFA Soccer 09',
#   'Need for Speed Underground 2',
#   'WWE SmackDown vs. Raw 2010',
#   'The Simpsons Game',
#   'Marvel: Ultimate Alliance',
#   'Tomb Raider: Underworld',
#   'Ice Age: Dawn of the Dinosaurs',
#   'Watch Dogs',
#   "Tony Hawk's Pro Skater 3",
#   'Juiced 2: Hot Import Nights',
#   'Darksiders II',
#   'Call of Duty: Ghosts',
#   'WWE SmackDown vs Raw 2008',
#   'LEGO Indiana Jones 2: The Adventure Continues',
#   'Madden NFL 2002',
#   'Sonic & All-Stars Racing Transformed',
#   'Just Dance 2015',
#   'Rayman Legends',
#   'Kung Fu Panda',
#   "Pirates of the Caribbean: At World's End",
#   'G-Force',
#   'Ben 10 Galactic Racing',
#   'Major League Baseball 2K12',
#   'Spider-Man 2',
#   'Just Dance 2017',
#   'DreamWorks Super Star Kartz',
#   "Cabela's North American Adventures",
#   'FIFA Soccer 06',
#   'Thor: God of Thunder',
#   'Karaoke Revolution',
#   "Tom Clancy's EndWar",
#   'Teenage Mutant Ninja Turtles',
#   'Rocksmith 2014',
#   'Harry Potter and the Deathly Hallows - Part 1',
#   'Scooby-Doo! Unmasked',
#   'Mini Ninjas',
#   'Crash of the Titans',
#   'The Chronicles of Narnia: The Lion, The Witch and The Wardrobe',
#   'Band Hero',
#   'LEGO Star Wars: The Video Game',
#   'Sleeping Dogs',
#   'Madden NFL 2005',
#   'Major League Baseball 2K9',
#   'Star Wars: The Force Unleashed II',
#   'Pro Evolution Soccer 2014',
#   'How to Train Your Dragon 2',
#   'Skylanders Giants',
#   'Captain America: Super Soldier',
#   'Call of Duty: Black Ops 3',
#   'Spider-Man: Edge of Time',
#   'Crash: Mind Over Mutant',
#   'Diablo III',
#   'Madagascar',
#   'Tomb Raider: Anniversary',
#   'Transformer: Rise of the Dark Spark',
#   'Monster Jam',
#   'Dark Souls II',
#   'Guitar Hero Live',
#   'Call of Duty: World at War',
#   'Call of Duty: Advanced Warfare',
#   'Need for Speed Underground',
#   'Bakugan: Battle Brawlers',
#   'Iron Man 2',
#   'Transformers: The Game (XBox 360, PS2, PS3, Wii & PC Versions)',
#   'Minecraft: Story Mode',
#   'Call of Duty: Black Ops',
#   'Jeopardy!',
#   'NBA 2K10',
#   'Metro: Last Light',
#   'Pinball Hall of Fame: The Williams Collection',
#   'F1 2011',
#   'Pro Evolution Soccer 2015',
#   'Marvel Super Hero Squad: The Infinity Gauntlet',
#   'FIFA Street 2',
#   'Pro Evolution Soccer 2008',
#   'Alien: Isolation',
#   'Battlefield: Hardline',
#   'Shrek the Third',
#   'Metal Gear Solid V: Ground Zeroes',
#   'Harry Potter and the Prisoner of Azkaban',
#   'FIFA 17',
#   'Farming Simulator 2015',
#   'Battlefield 4',
#   'NBA Live 08',
#   "Tony Hawk's Proving Ground",
#   'Dishonored',
#   'FIFA Street',
#   'Winning Eleven: Pro Evolution Soccer 2007',
#   'Metal Gear Solid V: The Phantom Pain',
#   'Saints Row IV',
#   'Need for Speed: The Run',
#   'Payday 2',
#   'Mortal Kombat',
#   'FIFA 16',
#   'Toy Story 3: The Video Game',
#   'Sherlock Holmes: Crimes & Punishments',
#   'Ben 10 Alien Force: Vilgax Attacks',
#   'Disney Infinity 3.0',
#   'Guitar Hero: World Tour',
#   'World Series of Poker 2008: Battle for the Bracelets',
#   'Pinball Hall of Fame: The Gottlieb Collection',
#   'Dead or Alive 5',
#   'Myst',
#   'Plants vs. Zombies: Garden Warfare',
#   'Far Cry 4',
#   'Fight Night Round 3',
#   'Wipeout 2',
#   'TRON: Evolution',
#   'Generator Rex: Agent of Providence',
#   'NBA 2K12',
#   'Fantastic Four: Rise of the Silver Surfer',
#   'Blazing Angels: Squadrons of WWII',
#   'Middle-Earth: Shadow of Mordor',
#   "The Lord of the Rings: Aragorn's Quest",
#   'Back to the Future: The Game',
#   'PES 2009: Pro Evolution Soccer',
#   'Skylanders Imaginators',
#   'Madden NFL 11',
#   'Resident Evil: Revelations',
#   'The Elder Scrolls V: Skyrim',
#   'Ride',
#   'The Walking Dead: Season Two',
#   'Monster Jam: Path of Destruction',
#   'Marvel Nemesis: Rise of the Imperfects',
#   'Madden NFL 10',
#   'Cloudy With a Chance of Meatballs',
#   'LEGO Dimensions',
#   'Transformers: Devastation',
#   'Tiger Woods PGA Tour 10',
#   'Dragon Age: Inquisition',
#   'Pro Evolution Soccer 2017',
#   'Major League Baseball 2K8',
#   'Injustice: Gods Among Us',
#   'Tomb Raider (2013)',
#   'The Chronicles of Narnia: Prince Caspian',
#   'Sega Superstars Tennis',
#   'MotoGP',
#   'NBA 2K16',
#   'The BIGS',
#   'The Legend of Spyro: Dawn of the Dragon',
#   'Wheel of Fortune',
#   'Happy Feet Two',
#   'Resident Evil: Revelations 2',
#   'Over the Hedge',
#   'Resident Evil 6',
#   'Grand Theft Auto V',
#   "Skylanders: Spyro's Adventure",
#   "SeaWorld Adventure Parks: Shamu's Deep Sea Adventure",
#   'Thrillville: Off the Rails',
#   'Wolfenstein: The New Order',
#   'Murdered: Soul Suspect',
#   'Thief (2014)',
#   'NBA 2K17',
#   'Pac-Man World 3',
#   'Ultimate Spider-Man',
#   'NBA 2K13',
#   'Shrek SuperSlam',
#   'Dead Rising 2',
#   'The Evil Within',
#   'The Wolf Among Us',
#   'The Smurfs 2',
#   'Bolt',
#   'SimCity 2000',
#   'Green Lantern: Rise of the Manhunters',
#   'Pro Evolution Soccer 2016',
#   'Bakugan Battle Brawlers: Defenders of the Core',
#   'WWE SmackDown vs. Raw 2011',
#   'Harry Potter and the Deathly Hallows - Part 2',
#   'Tiger Woods PGA Tour 06',
#   'Need for Speed Rivals',
#   'Rugby 15',
#   'Shaun White Snowboarding',
#   'Guitar Hero III: Legends of Rock',
#   'Major League Baseball 2K6',
#   'Grand Theft Auto: San Andreas',
#   "Cabela's Outdoor Adventures (2009)",
#   'Destiny: The Taken King',
#   'Attack on Titan (KOEI)',
#   'The Hobbit',
#   'SSX On Tour',
#   'Captain Morgane and the Golden Turtle',
#   'James Bond 007: Blood Stone',
#   'NHL 2K9',
#   'Star Wars: Battlefront II',
#   'Call of Duty 3',
#   'Borderlands 2',
#   'Disney Sing It',
#   'Guitar Hero: Van Halen',
#   'Mario Tennis',
#   'Tiger Woods PGA Tour 2005',
#   'UEFA Euro 2008 Austria-Switzerland',
#   'Cars: Mater-National Championship',
#   "Baldur's Gate: Dark Alliance",
#   'Pitfall: The Lost Expedition',
#   'Ben 10: Protector of Earth',
#   'Puss in Boots',
#   'Guitar Hero 5',
#   'NHL 07',
#   'Gun',
#   'The Penguins of Madagascar: Dr. Blowhole Returns - Again!',
#   'Karaoke Revolution Presents American Idol Encore',
#   'Barbie as The Island Princess',
#   'NCIS',
#   'Winter Sports 2: The Next Challenge',
#   'SSX 3',
#   'Guitar Hero: Smash Hits',
#   'Scooby-Doo! Mystery Mayhem',
#   'Resident Evil 4',
#   'Teenage Mutant Ninja Turtles 2: Battle Nexus',
#   'The Secret Saturdays: Beasts of the 5th Sun',
#   'Need for Speed: Hot Pursuit',
#   'Star Wars Episode III: Revenge of the Sith',
#   'Disney Sing It! High School Musical 3: Senior Year',
#   'Resident Evil Zero',
#   'Rock Band 2',
#   'Rock Revolution',
#   'MySims SkyHeroes',
#   '2010 FIFA World Cup South Africa',
#   'Monster House',
#   'Scarface: The World is Yours',
#   'Need for Speed: Shift',
#   'The SpongeBob SquarePants Movie',
#   'All-Star Baseball 2004',
#   'Sonic Generations',
#   'Virtua Tennis 3',
#   'Batman: A Telltale Game Series',
#   'NCAA Football 08',
#   'Avatar: The Last Airbender - The Burning Earth',
#   'Dave Mirra Freestyle BMX 2',
#   'Minority Report: Everybody Runs',
#   'Dreamworks Madagascar Kartz',
#   'Pac-Man World 2',
#   'Dead to Rights',
#   'WipeOut 3 The Game',
#   'From Russia With Love',
#   'Rock Band: Metal Track Pack',
#   'Jurassic: The Hunted',
#   'Batman: Rise of Sin Tzu',
#   "Cabela's Dangerous Hunts 2009",
#   'Puyo Puyo Tetris',
#   'Teenage Mutant Ninja Turtles 3: Mutant Nightmare',
#   'Mission: Impossible - Operation Surma',
#   'Sniper Elite 3',
#   'Defender',
#   'Bionicle Heroes',
#   'Monster Jam: Urban Assault',
#   'CSI: Fatal Conspiracy',
#   'IL-2 Sturmovik: Birds of Prey',
#   "SpongeBob's Truth or Square (US sales)",
#   'Crash Nitro Kart',
#   "The Sims: Bustin' Out",
#   'NPPL: Championship Paintball 2009',
#   'Teenage Mutant Ninja Turtles: Mutants in Manhattan',
#   'Ty the Tasmanian Tiger 2: Bush Rescue',
#   'World Series of Poker',
#   "Tom Clancy's Ghost Recon",
#   'NCAA Football 09',
#   'Curious George',
#   "Tony Hawk's Pro Skater 4",
#   'MotoGP 14 ',
#   'Split/Second',
#   'NBA 2K15',
#   'Steins;Gate',
#   'The Sims 2: Castaway',
#   'SpongeBob SquarePants: Lights, Camera, Pants!',
#   "Tony Hawk's Underground 2",
#   'Crash Tag Team Racing',
#   'Rayman Raving Rabbids',
#   'Tiger Woods PGA Tour 09',
#   'Marvel Super Hero Squad',
#   'Turok: Evolution',
#   'The Crew',
#   'X-Men Legends II: Rise of Apocalypse',
#   'Legend of Kay',
#   'Rugby League Live 3',
#   'NASCAR Unleashed',
#   'LEGO Rock Band',
#   'How to Train Your Dragon',
#   'NBA Live 06',
#   'Hot Wheels: Beat That!',
#   'Call of Duty: Modern Warfare 3',
#   'Ed, Edd n Eddy: The Mis-Edventures',
#   'Monster High: New Ghoul in School',
#   "Cabela's Big Game Hunter 2005 Adventures",
#   "Kelly Slater's Pro Surfer",
#   'Harry Potter: Quidditch World Cup',
#   'Shrek: Forever After',
#   "Adventure Time: Explore the Dungeon Because I Don't Know!",
#   'Madden NFL 15',
#   'The Sims',
#   'Guitar Hero: Aerosmith',
#   'Zapper: One Wicked Cricket!',
#   'Puzzle Quest: Challenge of the Warlords',
#   'Rayman 3: Hoodlum Havoc',
#   'WWE 2K16',
#   'Batman: Arkham Origins',
#   'NHL 09',
#   'Madden NFL 16',
#   'Bejeweled 3',
#   'James Bond 007: Everything or Nothing',
#   'Ty the Tasmanian Tiger 3: Night of the Quinkan',
#   'Sonic Unleashed',
#   'Major League Baseball 2K7',
#   'Shark Tale',
#   "Mat Hoffman's Pro BMX 2",
#   "Lemony Snicket's A Series of Unfortunate Events",
#   'Driver: San Francisco',
#   'Chaotic: Shadow Warriors',
#   'Reign of Fire',
#   'Where the Wild Things Are',
#   'Game of Thrones (Telltale)',
#   'The Lord of the Rings: The Return of the King',
#   'Deadpool',
#   'The Urbz: Sims in the City',
#   'Hitman: Blood Money',
#   "X2: Wolverine's Revenge",
#   'DuckTales: Remastered',
#   'World Poker Tour',
#   "Cabela's Dangerous Hunts 2011",
#   'Risen 3: Titan Lords',
#   'Bee Movie Game',
#   'Alone in the Dark',
#   'Top Spin 3',
#   'WRC: FIA World Rally Championship',
#   'Madden NFL 25',
#   'Batman: Arkham City',
#   'FIFA Soccer 2004',
#   'SBK Superbike World Championship',
#   'Destiny',
#   'James Bond 007: Nightfire',
#   'NBA 2K7',
#   'DJ Hero',
#   "Tony Hawk's Pro Skater 5",
#   'The Lord of the Rings: Conquest',
#   'Space Chimps',
#   'NCAA Football 10',
#   'DmC: Devil May Cry',
#   'Tak 2: The Staff of Dreams',
#   'Sniper Elite',
#   'Epic Mickey 2: The Power of Two',
#   'Avatar: The Last Airbender',
#   'Max Payne',
#   'Indiana Jones and the Staff of Kings',
#   'SSX Tricky',
#   'Street Fighter X Tekken',
#   "Tom Clancy's Splinter Cell: Pandora Tomorrow",
#   'Rio',
#   'The Simpsons: Road Rage',
#   'FIFA Soccer 2003',
#   'Sega Rally Revo',
#   'Planet 51',
#   'WWE 2K15',
#   'SpongeBob SquarePants: Battle for Bikini Bottom',
#   'Ben 10: Alien Force',
#   'Sonic the Hedgehog',
#   'Medal of Honor',
#   'Bionicle',
#   'Dynasty Warriors 8: Empires',
#   "Tom Clancy's Splinter Cell: Blacklist",
#   'Rise of the Tomb Raider',
#   'Rock Band Country Track Pack',
#   'Trivial Pursuit',
#   'Finding Nemo',
#   'Rock Band',
#   'AC/DC LIVE: Rock Band Track Pack',
#   'Starsky & Hutch',
#   'Mass Effect 3',
#   'World Series of Poker: Tournament of Champions 2007 Edition',
#   'GoldenEye: Rogue Agent',
#   'Namco Museum',
#   'Spider-Man: Shattered Dimensions',
#   'Batman Begins',
#   'Prince of Persia: The Sands of Time',
#   'NBA Live 07',
#   'Rango: The Video Game',
#   'NHL 2K10',
#   'Rock Band Track Pack Volume 2',
#   'Kung Fu Panda 2',
#   'Space Invaders',
#   "Tom Clancy's Splinter Cell: Double Agent",
#   "Legend of the Guardians: The Owls of Ga'Hoole",
#   "Tony Hawk's Underground",
#   'Madden NFL 12',
#   'Rock Band Track Pack: Classic Rock',
#   'Virtua Tennis 4',
#   'Rock Band 3',
#   'NHL 15',
#   'Charlie and the Chocolate Factory',
#   'Create',
#   "Disney's Chicken Little",
#   'The Ant Bully',
#   'The Croods: Prehistoric Party!',
#   'Clannad',
#   'Final Fantasy III',
#   'Tak: The Great Juju Challenge',
#   'Shaun White Skateboarding',
#   'MX vs. ATV Reflex',
#   'FIFA Soccer 2005',
#   'Namco Museum: 50th Anniversary',
#   'NBA 2K14',
#   'The Adventures of Tintin: The Game',
#   'The Lord of the Rings: The Two Towers',
#   'TNA iMPACT!',
#   "Disney's Meet the Robinsons",
#   'Hannah Montana: The Movie',
#   'All-Star Baseball 2003',
#   'Astro Boy: The Video Game',
#   'Dragon Ball: XenoVerse',
#   "Disney's Extreme Skate Adventure",
#   'Transformers: Dark of the Moon',
#   'Just Dance 4',
#   'Madden NFL 2003',
#   'Plants vs. Zombies',
#   'Legends of Wrestling II',
#   'Young Justice: Legacy',
#   'Madden NFL 17',
#   'Devil May Cry 4',
#   'X-Men Origins: Wolverine',
#   'SCORE International Baja 1000: The Official Game',
#   'LEGO Star Wars: The Complete Saga',
#   'Barnyard',
#   'TMNT',
#   'Call of Duty: Black Ops II',
#   'Backyard NFL Football',
#   'Big Mutha Truckers',
#   'Robots',
#   'Spider-Man: The Movie',
#   'WWE 2K17',
#   'Mortal Kombat: Deadly Alliance',
#   "Tony Hawk's Project 8",
#   'Deus Ex: Human Revolution',
#   'Pac-Man and the Ghostly Adventures 2',
#   "Assassin's Creed III",
#   'WRC 5: FIA World Rally Championship',
#   "Tom Clancy's Splinter Cell: Chaos Theory",
#   "Disney's Donald Duck: Goin' Quackers",
#   'de Blob 2',
#   'NCAA Football 07',
#   'GRID',
#   'Rugby Challenge 3',
#   "Disney's Planes",
#   'Tiger Woods PGA Tour 2004',
#   'Madden NFL 2004',
#   'NBA Live 09',
#   'Ford Racing 3',
#   "Tom Clancy's Splinter Cell",
#   'BlazBlue: Chrono Phantasma Extend',
#   'Call of Duty 4: Modern Warfare',
#   'X-Men: Destiny',
#   'Guitar Hero: Metallica',
#   'One Piece: Unlimited World Red',
#   "Tom Clancy's HAWX 2",
#   'PAC-MAN and the Ghostly Adventures',
#   'Bomberman',
#   'Catwoman',
#   'Battle vs. Chess',
#   'Strike Force Bowling',
#   'Rocket Power: Beach Bandits',
#   'The Voice',
#   "Assassin's Creed: Revelations",
#   "Tom Clancy's Ghost Recon Advanced Warfighter 2",
#   'Monster Hunter Tri',
#   'Transformers: Prime',
#   'NHL 2003',
#   'Beyond Good & Evil',
#   "Brothers in Arms: Hell's Highway",
#   'Transformers: War for Cybertron (XBox 360, PS3, & PC Versions)',
#   'The Bible Game',
#   'Steins;Gate: Hiyoku Renri no Darling',
#   'ATV Quad Power Racing 2',
#   'Area 51',
#   'Evolve',
#   "Tom Clancy's Rainbow Six: Lockdown",
#   'Petz: Catz 2',
#   "Tom Clancy's Ghost Recon 2",
#   'Trials Fusion',
#   'Dawn of Discovery',
#   'Blur',
#   'Scaler',
#   'Freestyle Metal X',
#   'Tekken 6',
#   "Cabela's Trophy Bucks",
#   'NBA 2K9',
#   'Battlefield 1',
#   'F1 2012',
#   'Bratz: Forever Diamondz',
#   'Medal of Honor: Airborne',
#   'Metal Gear Solid HD Edition',
#   'R.U.S.E.',
#   'Marvel Super Hero Squad: Comic Combat',
#   'Star Wars: Battlefront',
#   'Wallace & Gromit in Project Zoo',
#   'Fallout 3',
#   'Mortal Kombat 3',
#   'NBA Street Vol. 2',
#   'Buffy the Vampire Slayer: Chaos Bleeds',
#   "Hunted: The Demon's Forge",
#   'RedCard 20-03',
#   'Call of Juarez: The Cartel',
#   'Bulletstorm',
#   'NHL 06',
#   'The Lord of the Rings: War in the North',
#   'The Mummy: Tomb of the Dragon Emperor',
#   'Tak and the Power of Juju',
#   'Hasbro Family Game Night',
#   'Dark Souls III',
#   'Call of Juarez: Bound in Blood',
#   'Samurai Warriors 4: Empires',
#   'MLB SlugFest 20-04',
#   'Avatar: The Last Airbender - Into the Inferno',
#   'The Hustle: Detroit Streets',
#   'Looney Tunes: Back in Action',
#   'Petz: Horsez 2',
#   'NCAA Football 2005',
#   'Yoru no Nai Kuni',
#   'GRID Autosport',
#   'Greg Hastings Paintball 2',
#   'Mass Effect Trilogy',
#   'Need for Speed (2015)',
#   'Speed Kings',
#   'Samurai Warriors 2',
#   "Cabela's Big Game Hunter (2008)",
#   'Samurai Shodown Anthology',
#   'Army of Two: The 40th Day',
#   'Terminator 3: Rise of the Machines',
#   "Tom Clancy's Rainbow Six: Siege",
#   'Phineas and Ferb: Across the 2nd Dimension',
#   'Call of Duty: Modern Warfare 2',
#   'Heroes of the Pacific',
#   'NASCAR 08',
#   'Spartan: Total Warrior',
#   'Battlefield 2: Modern Combat',
#   'Smashing Drive',
#   'Battlezone',
#   'MX 2002 Featuring Ricky Carmichael',
#   'TOCA Race Driver 3',
#   'Metal Arms: Glitch in the System',
#   'Operation Flashpoint: Red River',
#   'Far Cry: Primal',
#   'NHL 16',
#   'Darksiders',
#   'Unreal Tournament III',
#   'The Naked Brothers Band: The Video Game',
#   'Chicken Shoot',
#   'Toukiden Kiwami',
#   'Midway Arcade Treasures',
#   'The Technomancer',
#   'Midway Arcade Treasures 3',
#   'Legacy of Kain: Defiance',
#   'Gauntlet: Dark Legacy',
#   'The Italian Job',
#   'XIII',
#   'BioShock Infinite',
#   'Fritz Chess',
#   'The Rise of the Argonauts',
#   'Scooby-Doo! Night of 100 Frights',
#   'Just Dance: Disney Party 2',
#   'Crysis 2',
#   "Tom Clancy's Ghost Recon: Future Soldier",
#   'F.E.A.R. 2: Project Origin',
#   'Sacred 2: Fallen Angel',
#   'Titanfall 2',
#   "Mirror's Edge Catalyst",
#   'World Championship Poker',
#   'Looney Tunes: Acme Arsenal',
#   'NBA Street V3',
#   'Shrek Super Party',
#   'Colin McRae Rally 04',
#   'Driver: Parallel Lines',
#   'The Chronicles of Riddick: Assault on Dark Athena',
#   'Boogie',
#   'Van Helsing',
#   'Rage',
#   'Samurai Warriors 4',
#   'Amagami',
#   'Batman: Arkham Knight',
#   'Spawn: Armageddon',
#   'Mafia II',
#   'Spec Ops: The Line',
#   'MXGP 2',
#   'Madden NFL 2001',
#   'Disney Sing It: Pop Hits',
#   'Dynasty Warriors: Eiketsuden',
#   'Overlord II',
#   "JASF: Jane's Advanced Strike Fighters",
#   'Chaos;Child',
#   'Arcania: Gothic 4',
#   'Ridge Racer Unbounded',
#   'Conflict: Desert Storm II - Back to Bagdhad',
#   'Disney Universe',
#   'Prince of Persia: The Two Thrones',
#   'Burnout Paradise: The Ultimate Box',
#   'Rampage: Total Destruction',
#   'Mass Effect 2',
#   'SpongeBob SquarePants featuring Nicktoons: Globs of Doom',
#   'BioShock 2',
#   'RoadKill',
#   'Harvey Birdman: Attorney at Law',
#   'TimeSplitters 2',
#   'Battleborn',
#   'Night at the Museum: Battle of the Smithsonian',
#   'SoulCalibur II',
#   'Overwatch',
#   'MX SuperFly featuring Ricky Carmichael',
#   'R: Racing Evolution',
#   'SpongeBob: HeroPants',
#   'Teen Titans',
#   'Silent Hill: Shattered Memories',
#   'NBA Live 2003',
#   'Kung Fu Panda: Showdown of Legendary Legends',
#   'SNK Arcade Classics Vol. 1',
#   'Dragon Ball Z: Sagas',
#   'Far Cry 3',
#   'Karaoke Revolution Presents American Idol Encore 2',
#   'GRID 2',
#   'Freekstyle',
#   'Wakeboarding Unleashed Featuring Shaun Murray',
#   'F1 2002',
#   'Crazy Taxi',
#   'Aggressive Inline',
#   'Star Trek: The Game',
#   'Tom and Jerry in War of the Whiskers',
#   'Aliens: Colonial Marines',
#   'Rocky',
#   'Red Faction II',
#   'NFL Blitz Pro',
#   'Scooby-Doo! and the Spooky Swamp',
#   'Dungeon Siege III',
#   'Hasbro Family Game Night 3',
#   'Dragon Quest Builders: Revive Alefgard',
#   'Hellboy: The Science of Evil',
#   'Farming Simulator 2013',
#   'Ski-Doo Snowmobile Challenge',
#   'Tiger Woods PGA Tour 12: The Masters',
#   'Saints Row 2',
#   'Despicable Me: The Game',
#   'Song of the Deep',
#   'South Park: The Stick of Truth',
#   'Tony Hawk: RIDE',
#   'Borderlands: The Pre-Sequel',
#   'Guitar Hero: Warriors of Rock',
#   "Sid Meier's Civilization Revolution",
#   'NBA 08',
#   'Legends of Wrestling',
#   'Battlefield: Bad Company 2',
#   'Future Tactics: The Uprising',
#   'Time Travelers',
#   'Driven',
#   'Final Fantasy XIV: Heavensward',
#   'Stormrise',
#   'High School Musical 3: Senior Year DANCE!',
#   'Beowulf: The Game',
#   'Dead Space',
#   'Pro Yakyuu Team o Tsukurou!',
#   'Digimon World 4',
#   'Aegis of Earth: Protonovus Assault',
#   'The Beatles: Rock Band',
#   'Fantastic 4',
#   'NASCAR Thunder 2002',
#   'Monster Jam: Maximum Destruction',
#   'Deus Ex: Mankind Divided',
#   "Fist of the North Star: Ken's Rage 2",
#   'Drome Racers',
#   'TimeShift',
#   'Carmen Sandiego: The Secret of the Stolen Drums',
#   'Stacked with Daniel Negreanu',
#   'X-Men Legends',
#   "Let's Dance with Mel B",
#   'Doom 3 BFG Edition',
#   'Dead Rising 2: Off the Record',
#   'NHL 2K7',
#   'Star Wars: Clone Wars',
#   'Warriors Orochi 2',
#   'Just Dance 3',
#   "The King of Fighters '95",
#   'Sword Art Online: Lost Song',
#   'The Lord of the Rings: The Third Age',
#   "Assassin's Creed II",
#   'PDC World Championship Darts 2008',
#   'Mercenaries 2: World in Flames',
#   'EA Sports Active 2',
#   'Defiance',
#   'F1 2010',
#   'Power Rangers: Dino Thunder',
#   'Nicktoons: MLB',
#   'One Piece: Pirate Warriors 3',
#   'Dynasty Warriors: Gundam 2',
#   'MLB 15: The Show',
#   "Assassin's Creed: Unity",
#   'Blazblue: Continuum Shift Extend',
#   'True Crime: New York City',
#   'The Legend of Heroes: Trails in the Sky Third Chapter',
#   'Enter the Matrix',
#   "Grey's Anatomy: The Video Game",
#   'Toukiden 2',
#   'The Elder Scrolls Online',
#   'Lost Planet 3',
#   "Tom Clancy's HAWX",
#   'NASCAR Thunder 2003',
#   'Resident Evil 5',
#   'SpongeBob SquarePants: Creature from the Krusty Krab',
#   'College Hoops 2K8',
#   'SSX',
#   'Terminator 3: The Redemption',
#   'Rapala Pro Fishing',
#   'Inversion',
#   'Mega Man Anniversary Collection',
#   'Just Cause 2',
#   'Sphinx and the Cursed Mummy',
#   'Bratz: Rock Angelz',
#   "Dragon Quest Heroes II: Twin Kings and the Prophecy's End",
#   'Virtua Tennis 2009',
#   'Fireblade',
#   'Dynasty Warriors 6',
#   'Supremacy MMA',
#   'Arcana Heart 3',
#   'Wreckless: ThE YaKuza MisSiOns',
#   'Mafia',
#   'Bad Boys: Miami Takedown',
#   'The Legend of Heroes: Trails in the Sky First Chapter',
#   'Plants vs. Zombies: Garden Warfare 2',
#   "Cabela's Dangerous Hunts 2",
#   'NBA 2K6',
#   'The Witcher 3: Wild Hunt',
#   'Midway Arcade Treasures 2',
#   'NBA Live 2005',
#   'Ready 2 Rumble Boxing: Round 2',
#   'Ultimate Marvel vs. Capcom 3',
#   'Angry Birds Trilogy',
#   'Freaky Flyers',
#   'NBA 2K8',
#   'Resident Evil',
#   'V-Rally 3',
#   'MVP Baseball 2005',
#   'Deadliest Catch: Sea of Chaos',
#   'Heavy Fire: Afghanistan',
#   'Nicktoons: Attack of the Toybots',
#   'NASCAR 2005: Chase for the Cup',
#   '428: Fuusa Sareta Shibuya de',
#   'NHL 2004',
#   'Mortal Kombat: Deception',
#   "Dora's Big Birthday Adventure",
#   '[Prototype 2]',
#   'NCAA Football 2004',
#   'The Crew: Wild Run',
#   "Disney's The Haunted Mansion",
#   'Singularity',
#   'Utawarerumono: Futari no Hakuoro',
#   'Theme Park',
#   '50 Cent: Bulletproof',
#   'Tiger Woods PGA Tour 2003',
#   'Dead Space 2',
#   'NBA Live 10',
#   'Brink',
#   'Warhammer 40,000: Space Marine',
#   'Burnout',
#   'Divinity: Original Sin',
#   'NHL Hitz Pro',
#   "Assassin's Creed Syndicate",
#   'Jurassic Park: Operation Genesis',
#   'Kingdoms of Amalur: Reckoning',
#   'Goblin Commander: Unleash the Horde',
#   'NHL Hitz 20-02',
#   'The Walking Dead: Survival Instinct',
#   'Transformers: Fall of Cybertron',
#   'Medal of Honor: Warfighter',
#   'Dishonored 2',
#   'Street Hoops',
#   'Top Gun: Combat Zones',
#   'Homefront: The Revolution',
#   'Fallout 4',
#   'Puzzle Challenge: Crosswords and More!',
#   'The Elder Scrolls IV: Oblivion',
#   'Burnout 2: Point of Impact',
#   'Little Busters! Converted Edition',
#   'NFL Street',
#   'The Legend of Spyro: The Eternal Night',
#   "Cabela's Adventure Camp",
#   'Driv3r',
#   'Risen 2: Dark Waters',
#   'Marvel vs. Capcom 2: New Age of Heroes',
#   "Cabela's Big Game Hunter 2012",
#   'Def Jam: Fight for NY',
#   'NHL Hitz 20-03',
#   'Corvette',
#   'Odin Sphere: Leifthrasir',
#   'Kane & Lynch 2: Dog Days',
#   'Winter Sports 3: The Great Tournament',
#   'Battlefield 3',
#   'Ford Racing Off Road',
#   'PDC World Championship Darts: Pro Tour',
#   'Sniper: Ghost Warrior 2',
#   'The Incredibles',
#   'Red Faction: Armageddon',
#   'Green Day: Rock Band',
#   'Final Fantasy XIV: A Realm Reborn',
#   'Second Sight',
#   'Atelier Sophie: The Alchemist of the Mysterious Book',
#   'The Cursed Crusade',
#   'Barbie and Her Sisters Puppy Rescue',
#   'The Simpsons: Hit & Run',
#   'True Crime: Streets of LA',
#   'NHL 2K6',
#   'X-Men Origins: Wolverine - Uncaged Edition',
#   "Disney's Winnie the Pooh's Rumbly Tumbly Adventure",
#   'MLB 14: The Show',
#   'FIFA Street 3',
#   'Barbie Horse Adventures: Riding Camp',
#   'Enemy Territory: Quake Wars',
#   'Wasteland 2',
#   'Pro Yaky? Spirits 2010',
#   'BioShock',
#   'Dynasty Warriors: Strikeforce',
#   'Mortal Kombat X',
#   'The Polar Express',
#   'Shovel Knight',
#   "Cabela's Legendary Adventures",
#   'Alpha Protocol',
#   'World Championship Poker 2: Featuring Howard Lederer',
#   'Alvin and the Chipmunks',
#   'NBA 2K2',
#   'Dead Rising',
#   'Project CARS',
#   'Mafia III',
#   'Ridge Racer',
#   'Pro Yaky? Spirits 2012',
#   'Venetica',
#   'Call of Duty: Infinite Warfare',
#   'Aliens vs Predator',
#   'Intellivision Lives!',
#   'Medal of Honor: Rising Sun',
#   'Penguins of Madagascar',
#   'Man vs. Wild',
#   'Scrabble',
#   'Pac-Man World Rally',
#   'Portal 2',
#   'Max Payne 2: The Fall of Max Payne',
#   'MotoGP 15',
#   "Tom Clancy's Rainbow Six 3",
#   'Turok',
#   'Just Cause',
#   'The Darkness II',
#   'UFC Personal Trainer: The Ultimate Fitness System',
#   'Titanfall',
#   'The King of Fighters Collection: The Orochi Saga',
#   'MotoGP 08',
#   "Tom Clancy's Rainbow Six: Vegas 2",
#   'Goosebumps HorrorLand',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'Shrek 2',
#   'Sonic & Sega All-Stars Racing',
#   'The Incredible Hulk: Ultimate Destruction',
#   'Backyard Baseball',
#   'Life is Strange',
#   'Disney Planes Fire & Rescue',
#   'Pro Yaky? Spirits 2013',
#   "Army Men: Sarge's Heroes 2",
#   'Crysis 3',
#   'MLB 09: The Show',
#   'College Hoops 2K6',
#   'Indigo Prophecy',
#   'The X-Factor',
#   'MLB 10: The Show',
#   "SpongeBob's Truth or Square",
#   'Rayman Arena',
#   'Jikkyou Powerful Pro Yakyuu 2013',
#   'National Geographic Challenge!',
#   'Dragon Age II',
#   'Conflict: Denied Ops',
#   'NFL Blitz 20-02',
#   "Spyro: A Hero's Tail",
#   'Nicktoons: Unite!',
#   'James Bond 007: Agent Under Fire',
#   'SpongeBob SquarePants: Revenge of the Flying Dutchman',
#   'Shadow The Hedgehog',
#   'Vexx',
#   'NFL Blitz 20-03',
#   'Dynasty Warriors 8: Xtreme Legends',
#   'NBA Live 2004',
#   "Akiba's Trip: Undead & Undressed",
#   'Manhunt 2',
#   'Monopoly Party',
#   'Crash Bandicoot: The Wrath of Cortex',
#   'NBA 07',
#   'F1 2015',
#   'Medal of Honor: Frontline',
#   'F1 Race Stars',
#   'NFL Street 2',
#   ...],
#  'Platform': ['PS2',
#   'DS',
#   'PS3',
#   'Wii',
#   'X360',
#   'PSP',
#   'PS',
#   'PC',
#   'XB',
#   'GBA',
#   'GC',
#   '3DS',
#   'PSV',
#   'PS4',
#   'N64',
#   'XOne',
#   'SNES',
#   'SAT',
#   'WiiU',
#   '2600',
#   'GB',
#   'NES',
#   'DC',
#   'GEN',
#   'NG',
#   'SCD',
#   'WS',
#   '3DO',
#   'TG16',
#   'PCFX',
#   'GG'],
#  'Publisher': ['Electronic Arts',
#   'Activision',
#   'Namco Bandai Games',
#   'Ubisoft',
#   'Konami Digital Entertainment',
#   'THQ',
#   'Nintendo',
#   'Sony Computer Entertainment',
#   'Sega',
#   'Take-Two Interactive',
#   'Capcom',
#   'Atari',
#   'Tecmo Koei',
#   'Warner Bros. Interactive Entertainment',
#   'Square Enix',
#   'Disney Interactive Studios',
#   'Unknown',
#   'Midway Games',
#   'Eidos Interactive',
#   '505 Games',
#   'Microsoft Game Studios',
#   'Acclaim Entertainment',
#   'D3Publisher',
#   'Vivendi Games',
#   'Codemasters',
#   'Idea Factory',
#   'Deep Silver',
#   'Nippon Ichi Software',
#   'Zoo Digital Publishing',
#   'Majesco Entertainment',
#   'LucasArts',
#   'Rising Star Games',
#   'Hudson Soft',
#   'Bethesda Softworks',
#   'Banpresto',
#   'Crave Entertainment',
#   'Atlus',
#   '5pb',
#   'Infogrames',
#   'Virgin Interactive',
#   'Ignition Entertainment',
#   'Focus Home Interactive',
#   'Marvelous Interactive',
#   'Empire Interactive',
#   'SquareSoft',
#   'Kadokawa Shoten',
#   'GT Interactive',
#   'PQube',
#   'Destineer',
#   'DTP Entertainment',
#   'Alchemist',
#   'MTV Games',
#   'Global Star',
#   'Takara Tomy',
#   'Nordic Games',
#   'Spike',
#   'SouthPeak Games',
#   'TDK Mediactive',
#   '3DO',
#   'BAM! Entertainment',
#   'Black Bean Games',
#   'Zoo Games',
#   'Psygnosis',
#   'Game Factory',
#   'Mindscape',
#   'Enix Corporation',
#   'Interplay',
#   'Prototype',
#   'Kalypso Media',
#   'Activision Value',
#   'FuRyu',
#   'Level 5',
#   'Telltale Games',
#   'Arc System Works',
#   'Avanquest',
#   'Little Orbit',
#   'Midas Interactive Entertainment',
#   'Jaleco',
#   'Aqua Plus',
#   'Paradox Interactive',
#   'Universal Interactive',
#   'JoWood Productions',
#   'Broccoli',
#   'SNK',
#   'Oxygen Interactive',
#   'Compile Heart',
#   'Kemco',
#   'ASCII Entertainment',
#   'Success',
#   'Taito',
#   'Titus',
#   'Storm City Games',
#   'City Interactive',
#   'Zushi Games',
#   'SNK Playmore',
#   'ChunSoft',
#   'Tomy Corporation',
#   'Natsume',
#   'Rocket Company',
#   'Koch Media',
#   'O-Games',
#   'SCi',
#   'DreamCatcher Interactive',
#   'Hasbro Interactive',
#   'Takara',
#   'GSP',
#   'Kadokawa Games',
#   'Imagineer',
#   'UFO Interactive',
#   'Falcom Corporation',
#   'Mastiff',
#   'Sony Computer Entertainment Europe',
#   'From Software',
#   'Ghostlight',
#   'PopCap Games',
#   'Milestone S.r.l.',
#   'Enterbrain',
#   'Quinrose',
#   'CyberFront',
#   '989 Studios',
#   'Playlogic Game Factory',
#   'System 3 Arcade Software',
#   'Play It',
#   'Conspiracy Entertainment',
#   'Rondomedia',
#   'Ubisoft Annecy',
#   'Ocean',
#   'Gust',
#   'GungHo',
#   'Acquire',
#   'Bigben Interactive',
#   'Nobilis',
#   'Human Entertainment',
#   'Mastertronic',
#   'XS Games',
#   'Metro 3D',
#   'Irem Software Engineering',
#   'Destination Software, Inc',
#   'Mattel Interactive',
#   'Marvelous Entertainment',
#   'Microids',
#   'Yeti',
#   'GameMill Entertainment',
#   'Sammy Corporation',
#   'Hudson Entertainment',
#   'Ackkstudios',
#   'Scholastic Inc.',
#   'Sunsoft',
#   'Starfish',
#   'Cave',
#   'Xplosiv',
#   'Brash Entertainment',
#   'Victor Interactive',
#   'NewKidCo',
#   'Sting',
#   'ASCII Media Works',
#   'Gathering of Developers',
#   'Foreign Media Games',
#   'Gremlin Interactive Ltd',
#   'Popcorn Arcade',
#   'ArtDink',
#   'Avanquest Software',
#   'RTL',
#   'Agetec',
#   'Fox Interactive',
#   'Asgard',
#   'Aksys Games',
#   'Genki',
#   'Telegames',
#   'MTO',
#   'Sony Online Entertainment',
#   'NEC Interchannel',
#   'JVC',
#   'Evolved Games',
#   'Aspyr',
#   'Gotham Games',
#   'LEGO Media',
#   'Reef Entertainment',
#   'Idea Factory International',
#   'Nippon Columbia',
#   'Astragon',
#   'Tru Blu Entertainment',
#   'Epoch',
#   'Valcon Games',
#   'Nihon Falcom Corporation',
#   'Rage Software',
#   'BMG Interactive Entertainment',
#   'Big Ben Interactive',
#   'Neko Entertainment',
#   'Hackberry',
#   'Parker Bros.',
#   'Benesse',
#   'Russel',
#   'Alternative Software',
#   'Square',
#   'Asylum Entertainment',
#   'Compile',
#   'Avalon Interactive',
#   'NCSoft',
#   'Mumbo Jumbo',
#   'Graffiti',
#   'Swing! Entertainment',
#   'Seta Corporation',
#   'Microprose',
#   'Paon',
#   'CDV Software Entertainment',
#   'Screenlife',
#   'Kaga Create',
#   'dramatic create',
#   'Blast! Entertainment Ltd',
#   'Comfort',
#   'Happinet',
#   'Pinnacle',
#   'Media Works',
#   'Hip Interactive',
#   'DSI Games',
#   'Mojang',
#   'AQ Interactive',
#   'Crystal Dynamics',
#   'Home Entertainment Suppliers',
#   'The Adventure Company',
#   'Tommo',
#   '20th Century Fox Video Games',
#   'Milestone S.r.l',
#   'Shogakukan',
#   'ESP',
#   'Mentor Interactive',
#   'IE Institute',
#   'Coleco',
#   'Xseed Games',
#   'Time Warner Interactive',
#   'TDK Core',
#   'bitComposer Games',
#   'Nordcurrent',
#   'Wanadoo',
#   'Funbox Media',
#   'FuRyu Corporation',
#   'System Soft',
#   'U.S. Gold',
#   'Trion Worlds',
#   'Video System',
#   'Imagic',
#   'Laguna',
#   'TopWare Interactive',
#   'Daito',
#   'RedOctane',
#   'Yacht Club Games',
#   'Mercury Games',
#   'Interchannel',
#   'Global A Entertainment',
#   'Pioneer LDC',
#   'Funsta',
#   'Touchstone',
#   'Gamecock',
#   'TGL',
#   'LSP Games',
#   'Knowledge Adventure',
#   'Focus Multimedia',
#   'Encore',
#   'Sunrise Interactive',
#   'Phenomedia',
#   'Slitherine Software',
#   'PlayV',
#   'KID',
#   'Excalibur Publishing',
#   'ValuSoft',
#   'Culture Brain',
#   'Essential Games',
#   'GN Software',
#   'Tradewest',
#   'Aruze Corp',
#   'Valve Software',
#   'NCS',
#   'MC2 Entertainment',
#   'NovaLogic',
#   'Iceberg Interactive',
#   'Myelin Media',
#   'Tigervision',
#   'Media Rings',
#   '1C Company',
#   'Vir2L Studios',
#   'Daedalic',
#   'Data Design Interactive',
#   '7G//AMES',
#   'Red Storm Entertainment',
#   'ASC Games',
#   'Sony Computer Entertainment America',
#   'Rebellion Developments',
#   'Minato Station',
#   'Tivola',
#   'Micro Cabin',
#   '10TACLE Studios',
#   'Asmik Ace Entertainment',
#   'Jester Interactive',
#   'DHM Interactive',
#   "Yuke's",
#   'Agatsuma Entertainment',
#   'O3 Entertainment',
#   'Accolade',
#   'Daedalic Entertainment',
#   'Experience Inc.',
#   'Princess Soft',
#   'Arika',
#   'Licensed 4U',
#   'Insomniac Games',
#   'Slightly Mad Studios',
#   'Jack of All Games',
#   'Hect',
#   'Telstar',
#   'Aerosoft',
#   'Indie Games',
#   'Angel Studios',
#   'Ascaron Entertainment GmbH',
#   'Maxis',
#   'Xicat Interactive',
#   'Mad Catz',
#   'NEC',
#   'Mud Duck Productions',
#   'Jorudan',
#   'Creative Core',
#   'P2 Games',
#   'Nippon Telenet',
#   'Vatical Entertainment',
#   'Pack-In-Video',
#   'Nitroplus',
#   'Coconuts Japan',
#   'Elf',
#   'Hamster Corporation',
#   'Rebellion',
#   'Alawar Entertainment',
#   'Blue Byte',
#   'Data East',
#   'Devolver Digital',
#   'Sonnet',
#   'Media Factory',
#   'Liquid Games',
#   'HMH Interactive',
#   'Tripwire Interactive',
#   'NetRevo',
#   'Dusenberry Martin Racing',
#   'Asmik Corp',
#   'Zenrin',
#   'Dorart',
#   'Funcom',
#   'imageepoch Inc.',
#   'CCP',
#   'Electronic Arts Victor',
#   'Datam Polystar',
#   'BPS',
#   'Misawa',
#   'Mamba Games',
#   'Data Age',
#   'G.Rev',
#   'MLB.com',
#   'Core Design Ltd.',
#   'Magix',
#   'Harmonix Music Systems',
#   'responDESIGN',
#   'Flashpoint Games',
#   'Syscom',
#   'Arena Entertainment',
#   'Lexicon Entertainment',
#   'Office Create',
#   'Groove Games',
#   'Red Orb',
#   'Sold Out',
#   'Crimson Cow',
#   'Gainax Network Systems',
#   'Square Enix ',
#   'Vic Tokai',
#   'System 3',
#   'Athena',
#   'Gakken',
#   'Edia',
#   'Sweets',
#   'Performance Designed Products',
#   'HuneX',
#   'Stainless Games',
#   'Flight-Plan',
#   'Gearbox Software',
#   'Game Life',
#   'Gamebridge',
#   'Introversion Software',
#   'Big Fish Games',
#   'Revolution Software',
#   'Easy Interactive',
#   'Alvion',
#   'Virtual Play Games',
#   'Views',
#   'Moss',
#   'Yamasa Entertainment',
#   'Cloud Imperium Games Corporation',
#   'CTO SpA',
#   'Sony Music Entertainment',
#   'CokeM Interactive',
#   'Phantom EFX',
#   'Navarre Corp',
#   'Mycom',
#   'FunSoft',
#   'Pack In Soft',
#   'The Learning Company',
#   'inXile Entertainment',
#   'Visco',
#   'Men-A-Vision',
#   'King Records',
#   'Strategy First',
#   'Aques',
#   'Seventh Chord',
#   'Milestone',
#   'Wizard Video Games',
#   'Game Arts',
#   'Adeline Software',
#   'Maximum Family Games',
#   'Merscom LLC',
#   'Xing Entertainment',
#   'Commseed',
#   'SCS Software',
#   '2D Boy',
#   'Fields',
#   'SSI',
#   'Axela',
#   'Universal Gamex',
#   'Tetris Online',
#   'Sears',
#   'Paradox Development',
#   'Ecole',
#   'TalonSoft',
#   'Quest',
#   'General Entertainment',
#   'Fuji',
#   'Square EA',
#   'ITT Family Games',
#   'Yumedia',
#   'Wargaming.net',
#   'UEP Systems',
#   'Locus',
#   'Sunflowers',
#   'Hearty Robin',
#   'Fortyfive',
#   'T&E Soft',
#   'Culture Publishers',
#   'Legacy Interactive',
#   'PopTop Software',
#   'Image Epoch',
#   'RED Entertainment',
#   'Number None',
#   'GOA',
#   'Magical Company',
#   'Valve',
#   'Epic Games',
#   'Saurus',
#   'EA Games',
#   '989 Sports',
#   'HAL Laboratory',
#   'MediaQuest',
#   'Glams',
#   'Quelle',
#   'Technos Japan Corporation',
#   'Interplay Productions',
#   'Gameloft',
#   'Team17 Software',
#   'American Softworks',
#   'Crytek',
#   'Bomb',
#   'NDA Productions',
#   'White Park Bay Software',
#   'Activision Blizzard',
#   'mixi, Inc',
#   'Marvel Entertainment',
#   'Otomate',
#   'Monte Christo Multimedia',
#   'Mystique',
#   'Starpath Corp.',
#   'Nichibutsu',
#   '49Games',
#   'Playmore',
#   'Interworks Unlimited, Inc.',
#   'Mitsui',
#   'Cygames',
#   'Aria',
#   'Takuyo',
#   'Illusion Softworks',
#   'Grand Prix Games',
#   'Quintet',
#   'Pony Canyon',
#   'Piacci',
#   'Imageworks',
#   'Ivolgamus',
#   'Revolution (Japan)',
#   'Summitsoft',
#   'WayForward Technologies',
#   'Panther Software',
#   'Elite',
#   'Kando Games',
#   'Lighthouse Interactive',
#   'DigiCube',
#   'Ongakukan',
#   'Nippon Amuse',
#   'Plenty',
#   'Vap',
#   'Giza10',
#   'Ascaron Entertainment',
#   'Simon & Schuster Interactive',
#   'TOHO',
#   'Gaga',
#   'Codemasters Online',
#   'Masque Publishing',
#   'Red Flagship',
#   'Boost On',
#   'Bohemia Interactive',
#   'Michaelsoft',
#   'CBS Electronics',
#   'Ultravision',
#   'iWin',
#   'Marvelous Games',
#   'Nexon',
#   'CPG Products',
#   'Phantagram',
#   'Answer Software',
#   'Riverhillsoft',
#   'DreamWorks Interactive',
#   'Hello Games',
#   'GameTek',
#   'Just Flight',
#   'Interchannel-Holon',
#   'Kool Kizz',
#   'Games Workshop',
#   'Genterprise',
#   'PM Studios',
#   'id Software',
#   'Pow',
#   'Altron',
#   'Playmates',
#   'Karin Entertainment',
#   'Detn8 Games',
#   'Her Interactive',
#   'Extreme Entertainment Group',
#   'Palcom',
#   'Kids Station',
#   'TYO',
#   'Kamui',
#   'Westwood Studios',
#   'Graphsim Entertainment',
#   'UIG Entertainment',
#   'Inti Creates',
#   'Max Five',
#   'Type-Moon',
#   'KSS',
#   'Imax',
#   'Havas Interactive',
#   'Paon Corporation',
#   'Berkeley',
#   'Ertain',
#   'Warashi',
#   'Mirai Shounen',
#   'Giga',
#   'Enjoy Gaming ltd.',
#   'Media Entertainment',
#   'Warp',
#   'Origin Systems',
#   'Evolution Games',
#   'Phoenix Games',
#   'Abylight',
#   'Societa',
#   'Kokopeli Digital Studios',
#   'Imadio',
#   'New',
#   'TechnoSoft',
#   'Naxat Soft',
#   'Black Label Games',
#   'Griffin International',
#   'Headup Games',
#   'New World Computing',
#   'SPS',
#   'ASK',
#   'Tryfirst',
#   'fonfun',
#   'On Demand',
#   'BushiRoad',
#   'EON Digital Entertainment',
#   'Pacific Century Cyber Works'],
#  'Rating': ['E', 'T', 'M', 'E10+', 'EC', 'RP', 'K-A', 'AO']}

# %% [markdown]
# # Modelo de regresión

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,SGDRegressor

steps = [('preproceso',dummy_games(col_scores=col_scores,cat_usr=cat_names)), 
         ('regresion',LinearRegression())
         ]
metodo_full = Pipeline(steps=steps)
metodo_full

metodo_full.fit(df_train,ytrain) #entrena todos los pasos
# Out:
# Pipeline(memory=None,
#          steps=[('preproceso',
#                  dummy_games(cat_usr={'Developer': ['Ubisoft', 'EA Sports',
#                                                     'EA Canada', 'Konami',
#                                                     'Capcom', 'EA Tiburon',
#                                                     'Electronic Arts',
#                                                     'Ubisoft Montreal',
#                                                     'Visual Concepts',
#                                                     'Omega Force',
#                                                     "Traveller's Tales",
#                                                     'Vicarious Visions',
#                                                     'Activision', 'TT Games',
#                                                     'Nintendo', 'THQ', 'Namco',
#                                                     'Codemasters',
#                                                     'Artificial Mind and '
#                                                     'Movement',
#                                                     'Midway', "Yuke's"...
#                                                     'Microsoft Game Studios',
#                                                     'Acclaim Entertainment',
#                                                     'D3Publisher',
#                                                     'Vivendi Games',
#                                                     'Codemasters',
#                                                     'Idea Factory',
#                                                     'Deep Silver',
#                                                     'Nippon Ichi Software',
#                                                     'Zoo Digital Publishing',
#                                                     'Majesco Entertainment', ...],
#                                       'Rating': ['E', 'T', 'M', 'E10+', 'EC',
#                                                  'RP', 'K-A', 'AO']},
#                              col_scores=None)),
#                 ('regresion',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
ytest_e = metodo_full.predict(df_test)
metodo_full[1].coef_
# Out:
# array([-2.74174703e-05, -1.91477815e-02, -2.40921462e-02, -3.33722355e-03,
#        -6.37800859e-04, -5.70590914e-01, -6.56781853e-01, -5.65986002e-01,
#        -4.94396391e-01,  5.60369444e-01,  4.50001873e-02,  3.83014310e-02,
#        -4.10578394e-04,  4.79564218e-04,  2.46802776e-01])

# %%
len(ytest)
len(ytest_e)
np.linalg.norm(ytest-ytest_e)
# Out:
# 78.07562072312724

# %%
ytest
# Out:
# array([4.98947368, 7.2       , 4.98947368, ..., 4.98947368, 4.98947368,
#        8.2       ])

# %%
ytest_e
# Out:
# array([5.43908419, 6.45765582, 5.40505281, ..., 5.37554543, 5.66310132,
#        6.36164577])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5016 entries, 5562 to 804
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5015 non-null   object
#  1   Platform         5016 non-null   object
#  2   Year_of_Release  4923 non-null   float64
#  3   Genre            5015 non-null   object
#  4   Publisher        4999 non-null   object
#  5   NA_Sales         5016 non-null   float64
#  6   EU_Sales         5016 non-null   float64
#  7   JP_Sales         5016 non-null   float64
#  8   Other_Sales      5016 non-null   float64
#  9   Global_Sales     5016 non-null   float64
#  10  Critic_Score     2446 non-null   float64
#  11  Critic_Count     2446 non-null   float64
#  12  User_Count       2268 non-null   float64
#  13  Developer        3013 non-null   object
#  14  Rating           2971 non-null   object
# dtypes: float64(9), object(6)
# memory usage: 627.0+ KB

# %%
plt.scatter(ytest,ytest_e)

# %%
metodo_full.steps[1][1]
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
metodo_full
# Out:
# Pipeline(memory=None,
#          steps=[('preproceso',
#                  dummy_games(cat_usr={'Developer': ['Ubisoft', 'EA Sports',
#                                                     'EA Canada', 'Konami',
#                                                     'Capcom', 'EA Tiburon',
#                                                     'Electronic Arts',
#                                                     'Ubisoft Montreal',
#                                                     'Visual Concepts',
#                                                     'Omega Force',
#                                                     "Traveller's Tales",
#                                                     'Vicarious Visions',
#                                                     'Activision', 'TT Games',
#                                                     'Nintendo', 'THQ', 'Namco',
#                                                     'Codemasters',
#                                                     'Artificial Mind and '
#                                                     'Movement',
#                                                     'Midway', "Yuke's"...
#                                                     'Microsoft Game Studios',
#                                                     'Acclaim Entertainment',
#                                                     'D3Publisher',
#                                                     'Vivendi Games',
#                                                     'Codemasters',
#                                                     'Idea Factory',
#                                                     'Deep Silver',
#                                                     'Nippon Ichi Software',
#                                                     'Zoo Digital Publishing',
#                                                     'Majesco Entertainment', ...],
#                                       'Rating': ['E', 'T', 'M', 'E10+', 'EC',
#                                                  'RP', 'K-A', 'AO']},
#                              col_scores=None)),
#                 ('regresion',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)
